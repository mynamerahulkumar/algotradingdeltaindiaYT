# %%
pip install delta-rest-client
# Out:
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# Requirement already satisfied: delta-rest-client in /opt/anaconda3/lib/python3.12/site-packages (1.0.12)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Symbol Management / Ticker /Filter Options Strike

# %%
import os
from dotenv import load_dotenv
load_dotenv()

apikey=os.getenv('DELTA_API_KEY')
apiSecret=os.getenv('DELTA_API_SECRET')

# %%
from delta_rest_client import DeltaRestClient
import pandas as pd
from datetime import datetime , timedelta

delta_client = DeltaRestClient(
  base_url='https://api.india.delta.exchange',
  api_key=apikey,
  api_secret=apiSecret
)
delta_client

# %% [markdown]
# ## Get Master List

# %%
# Get symbol list
res = delta_client.get_product('')
symdf = pd.DataFrame(res)
symdf
# Out:
#      maker_commission_rate      disruption_reason  \
# 0                  0.00015  New Contract Launched
# 1                  0.00015  New Contract Launched
# 2                  0.00015  New Contract Launched
# 3                  0.00015                   None
# 4                  0.00015                   None
# ...                    ...                    ...
# 1037                0.0002                   None
# 1038                0.0002                   None
# 1039                0.0002                   None
# 1040                0.0002                   None
# 1041                0.0002                   None
#
#      insurance_fund_margin_contribution       settlement_time  \
# 0                                     5  2025-08-09T12:00:00Z
# 1                                     5  2025-08-09T12:00:00Z
# 2                                     5  2025-08-09T12:00:00Z
# 3                                     5  2025-08-09T12:00:00Z
# 4                                     5  2025-08-07T12:00:00Z
# ...                                 ...                   ...
# 1037                                  5                  None
# 1038                                  5                  None
# 1039                                  5                  None
# 1040                                  5                  None
# 1041                                  5                  None
#
#                                           quoting_asset  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...
# 1     {'base_withdrawal_fee': '0.000000000000000000'...
# 2     {'base_withdrawal_fee': '0.000000000000000000'...
# 3     {'base_withdrawal_fee': '0.000000000000000000'...
# 4     {'base_withdrawal_fee': '0.000000000000000000'...
# ...                                                 ...
# 1037  {'base_withdrawal_fee': '0.000000000000000000'...
# 1038  {'base_withdrawal_fee': '0.000000000000000000'...
# 1039  {'base_withdrawal_fee': '0.000000000000000000'...
# 1040  {'base_withdrawal_fee': '0.000000000000000000'...
# 1041  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                        underlying_asset       trading_status  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...  disrupted_post_only
# 1     {'base_withdrawal_fee': '0.000000000000000000'...  disrupted_post_only
# 2     {'base_withdrawal_fee': '0.000000000000000000'...  disrupted_post_only
# 3     {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 4     {'base_withdrawal_fee': '0.000000000000000000'...          operational
# ...                                                 ...                  ...
# 1037  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1038  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1039  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1040  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1041  {'base_withdrawal_fee': '0.000000000000000000'...          operational
#
#      liquidation_penalty_factor  impact_size state  ...    auction_start_time  \
# 0                           0.5          300  live  ...  2025-08-06T15:55:16Z
# 1                           0.5          300  live  ...  2025-08-06T15:55:15Z
# 2                           0.5          200  live  ...  2025-08-06T15:55:09Z
# 3                           0.5          300  live  ...  2025-08-06T15:40:16Z
# 4                           0.5          200  live  ...  2025-08-06T15:40:06Z
# ...                         ...          ...   ...  ...                   ...
# 1037                        0.2         2469  live  ...  2025-07-27T05:47:40Z
# 1038                        0.2         1500  live  ...  2025-07-27T05:47:41Z
# 1039                        0.2         5282  live  ...  2025-07-27T05:47:41Z
# 1040                        0.2         9591  live  ...  2025-07-27T05:47:40Z
# 1041                        0.5        10000  live  ...  2025-07-27T05:47:41Z
#
#       strike_price               symbol    short_description  \
# 0             3740    C-ETH-3740-090825            ETH  Call
# 1             3740    P-ETH-3740-090825             ETH  Put
# 2           118000  P-BTC-118000-090825             BTC  Put
# 3             3840    P-ETH-3840-090825             ETH  Put
# 4           116600  C-BTC-116600-070825            BTC  Call
# ...            ...                  ...                  ...
# 1037          None              AVAXUSD  Avalanche Perpetual
# 1038          None               SOLUSD     Solana Perpetual
# 1039          None              DOGEUSD   Dogecoin Perpetual
# 1040          None               ETHUSD   Ethereum Perpetual
# 1041          None               BTCUSD    Bitcoin Perpetual
#
#                                              spot_index  \
# 0     {'config': {'price_alert_enabled': True, 'quot...
# 1     {'config': {'price_alert_enabled': True, 'quot...
# 2     {'config': {'price_alert_enabled': True, 'quot...
# 3     {'config': {'price_alert_enabled': True, 'quot...
# 4     {'config': {'price_alert_enabled': True, 'quot...
# ...                                                 ...
# 1037  {'config': {'price_alert_enabled': True, 'quot...
# 1038  {'config': {'price_alert_enabled': True, 'quot...
# 1039  {'config': {'price_alert_enabled': True, 'quot...
# 1040  {'config': {'price_alert_enabled': True, 'quot...
# 1041  {'config': {'price_alert_enabled': True, 'quot...
#
#                                           product_specs taker_commission_rate  \
# 0     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 1     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 2     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 3     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 4     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# ...                                                 ...                   ...
# 1037  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1038  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1039  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1040  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1041  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
#
#                                             description initial_margin  \
# 0                  ETH call option expiring on 9-8-2025              1
# 1                   ETH put option expiring on 9-8-2025              1
# 2                   BTC put option expiring on 9-8-2025              1
# 3                   ETH put option expiring on 9-8-2025              1
# 4                  BTC call option expiring on 7-8-2025            0.5
# ...                                                 ...            ...
# 1037            Avalance perpetual future quoted in USD              1
# 1038              Solana perpetual future quoted in USD              1
# 1039            Dogecoin perpetual future quoted in USD              1
# 1040  Ethereum Perpetual futures, quoted, settled & ...            0.5
# 1041  Bitcoin Perpetual futures, quoted, settled & m...            0.5
#
#      initial_margin_scaling_factor
# 0                         0.000004
# 1                         0.000004
# 2                         0.000002
# 3                         0.000004
# 4                         0.000002
# ...                            ...
# 1037                      0.000004
# 1038                      0.000004
# 1039                      0.000004
# 1040                      0.000004
# 1041                     0.0000025
#
# [1042 rows x 42 columns]

# %%
symdf.contract_type.unique()
# Out:
# array(['call_options', 'put_options', 'perpetual_futures', 'tracker'],
#       dtype=object)

# %%
symdf.iloc[0]
# Out:
# maker_commission_rate                                                           0.00015
# disruption_reason                                                 New Contract Launched
# insurance_fund_margin_contribution                                                    5
# settlement_time                                                    2025-08-09T12:00:00Z
# quoting_asset                         {'base_withdrawal_fee': '0.000000000000000000'...
# underlying_asset                      {'base_withdrawal_fee': '0.000000000000000000'...
# trading_status                                                      disrupted_post_only
# liquidation_penalty_factor                                                          0.5
# impact_size                                                                         300
# state                                                                              live
# settling_asset                        {'base_withdrawal_fee': '0.000000000000000000'...
# id                                                                                88426
# tick_size                                                                          0.01
# barrier_price                                                                      None
# auction_finish_time                                                2025-08-06T16:05:16Z
# annualized_funding                                                                10.95
# funding_method                                                               mark_price
# is_quanto                                                                         False
# max_leverage_notional                                                            100000
# launch_time                                                        2025-08-06T15:55:16Z
# contract_unit_currency                                                              ETH
# contract_type                                                              call_options
# maintenance_margin                                                                  0.5
# basis_factor_max_limit                                                            10.95
# notional_type                                                                   vanilla
# price_band                                                                            2
# position_size_limit                                                              173467
# settlement_price                                                                   None
# contract_value                                                                     0.01
# maintenance_margin_scaling_factor                                              0.000002
# ui_config                             {'default_trading_view_candle': '15', 'leverag...
# default_leverage                                                 100.000000000000000000
# auction_start_time                                                 2025-08-06T15:55:16Z
# strike_price                                                                       3740
# symbol                                                                C-ETH-3740-090825
# short_description                                                             ETH  Call
# spot_index                            {'config': {'price_alert_enabled': True, 'quot...
# product_specs                         {'backup_vol_expiry_time': 31536000, 'isolated...
# taker_commission_rate                                                           0.00015
# description                                        ETH call option expiring on 9-8-2025
# initial_margin                                                                        1
# initial_margin_scaling_factor                                                  0.000004
# Name: 0, dtype: object

# %%
symdf['settlement_time'] =pd.to_datetime(symdf['settlement_time'], utc=True)
symdf['expiry'] = symdf['settlement_time'].dt.date
symdf
# Out:
#      maker_commission_rate      disruption_reason  \
# 0                  0.00015  New Contract Launched
# 1                  0.00015  New Contract Launched
# 2                  0.00015  New Contract Launched
# 3                  0.00015                   None
# 4                  0.00015                   None
# ...                    ...                    ...
# 1037                0.0002                   None
# 1038                0.0002                   None
# 1039                0.0002                   None
# 1040                0.0002                   None
# 1041                0.0002                   None
#
#      insurance_fund_margin_contribution           settlement_time  \
# 0                                     5 2025-08-09 12:00:00+00:00
# 1                                     5 2025-08-09 12:00:00+00:00
# 2                                     5 2025-08-09 12:00:00+00:00
# 3                                     5 2025-08-09 12:00:00+00:00
# 4                                     5 2025-08-07 12:00:00+00:00
# ...                                 ...                       ...
# 1037                                  5                       NaT
# 1038                                  5                       NaT
# 1039                                  5                       NaT
# 1040                                  5                       NaT
# 1041                                  5                       NaT
#
#                                           quoting_asset  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...
# 1     {'base_withdrawal_fee': '0.000000000000000000'...
# 2     {'base_withdrawal_fee': '0.000000000000000000'...
# 3     {'base_withdrawal_fee': '0.000000000000000000'...
# 4     {'base_withdrawal_fee': '0.000000000000000000'...
# ...                                                 ...
# 1037  {'base_withdrawal_fee': '0.000000000000000000'...
# 1038  {'base_withdrawal_fee': '0.000000000000000000'...
# 1039  {'base_withdrawal_fee': '0.000000000000000000'...
# 1040  {'base_withdrawal_fee': '0.000000000000000000'...
# 1041  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                        underlying_asset       trading_status  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...  disrupted_post_only
# 1     {'base_withdrawal_fee': '0.000000000000000000'...  disrupted_post_only
# 2     {'base_withdrawal_fee': '0.000000000000000000'...  disrupted_post_only
# 3     {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 4     {'base_withdrawal_fee': '0.000000000000000000'...          operational
# ...                                                 ...                  ...
# 1037  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1038  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1039  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1040  {'base_withdrawal_fee': '0.000000000000000000'...          operational
# 1041  {'base_withdrawal_fee': '0.000000000000000000'...          operational
#
#      liquidation_penalty_factor  impact_size state  ... strike_price  \
# 0                           0.5          300  live  ...         3740
# 1                           0.5          300  live  ...         3740
# 2                           0.5          200  live  ...       118000
# 3                           0.5          300  live  ...         3840
# 4                           0.5          200  live  ...       116600
# ...                         ...          ...   ...  ...          ...
# 1037                        0.2         2469  live  ...         None
# 1038                        0.2         1500  live  ...         None
# 1039                        0.2         5282  live  ...         None
# 1040                        0.2         9591  live  ...         None
# 1041                        0.5        10000  live  ...         None
#
#                    symbol    short_description  \
# 0       C-ETH-3740-090825            ETH  Call
# 1       P-ETH-3740-090825             ETH  Put
# 2     P-BTC-118000-090825             BTC  Put
# 3       P-ETH-3840-090825             ETH  Put
# 4     C-BTC-116600-070825            BTC  Call
# ...                   ...                  ...
# 1037              AVAXUSD  Avalanche Perpetual
# 1038               SOLUSD     Solana Perpetual
# 1039              DOGEUSD   Dogecoin Perpetual
# 1040               ETHUSD   Ethereum Perpetual
# 1041               BTCUSD    Bitcoin Perpetual
#
#                                              spot_index  \
# 0     {'config': {'price_alert_enabled': True, 'quot...
# 1     {'config': {'price_alert_enabled': True, 'quot...
# 2     {'config': {'price_alert_enabled': True, 'quot...
# 3     {'config': {'price_alert_enabled': True, 'quot...
# 4     {'config': {'price_alert_enabled': True, 'quot...
# ...                                                 ...
# 1037  {'config': {'price_alert_enabled': True, 'quot...
# 1038  {'config': {'price_alert_enabled': True, 'quot...
# 1039  {'config': {'price_alert_enabled': True, 'quot...
# 1040  {'config': {'price_alert_enabled': True, 'quot...
# 1041  {'config': {'price_alert_enabled': True, 'quot...
#
#                                           product_specs taker_commission_rate  \
# 0     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 1     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 2     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 3     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 4     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# ...                                                 ...                   ...
# 1037  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1038  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1039  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1040  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1041  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
#
#                                             description  initial_margin  \
# 0                  ETH call option expiring on 9-8-2025               1
# 1                   ETH put option expiring on 9-8-2025               1
# 2                   BTC put option expiring on 9-8-2025               1
# 3                   ETH put option expiring on 9-8-2025               1
# 4                  BTC call option expiring on 7-8-2025             0.5
# ...                                                 ...             ...
# 1037            Avalance perpetual future quoted in USD               1
# 1038              Solana perpetual future quoted in USD               1
# 1039            Dogecoin perpetual future quoted in USD               1
# 1040  Ethereum Perpetual futures, quoted, settled & ...             0.5
# 1041  Bitcoin Perpetual futures, quoted, settled & m...             0.5
#
#      initial_margin_scaling_factor      expiry
# 0                         0.000004  2025-08-09
# 1                         0.000004  2025-08-09
# 2                         0.000002  2025-08-09
# 3                         0.000004  2025-08-09
# 4                         0.000002  2025-08-07
# ...                            ...         ...
# 1037                      0.000004         NaT
# 1038                      0.000004         NaT
# 1039                      0.000004         NaT
# 1040                      0.000004         NaT
# 1041                     0.0000025         NaT
#
# [1042 rows x 43 columns]

# %%
expiryDate= datetime.now() +  timedelta(days=1)
btcdf = symdf[(symdf.expiry ==expiryDate.date() )& (symdf.contract_unit_currency == 'BTC') ]
btcdf
# Out:
#     maker_commission_rate disruption_reason  \
# 4                 0.00015              None
# 5                 0.00015              None
# 94                0.00015              None
# 95                0.00015              None
# 100               0.00015              None
# ..                    ...               ...
# 260               0.00015              None
# 261               0.00015              None
# 262               0.00015              None
# 263               0.00015              None
# 264               0.00015              None
#
#     insurance_fund_margin_contribution           settlement_time  \
# 4                                    5 2025-08-07 12:00:00+00:00
# 5                                    5 2025-08-07 12:00:00+00:00
# 94                                   5 2025-08-07 12:00:00+00:00
# 95                                   5 2025-08-07 12:00:00+00:00
# 100                                  5 2025-08-07 12:00:00+00:00
# ..                                 ...                       ...
# 260                                  5 2025-08-07 12:00:00+00:00
# 261                                  5 2025-08-07 12:00:00+00:00
# 262                                  5 2025-08-07 12:00:00+00:00
# 263                                  5 2025-08-07 12:00:00+00:00
# 264                                  5 2025-08-07 12:00:00+00:00
#
#                                          quoting_asset  \
# 4    {'base_withdrawal_fee': '0.000000000000000000'...
# 5    {'base_withdrawal_fee': '0.000000000000000000'...
# 94   {'base_withdrawal_fee': '0.000000000000000000'...
# 95   {'base_withdrawal_fee': '0.000000000000000000'...
# 100  {'base_withdrawal_fee': '0.000000000000000000'...
# ..                                                 ...
# 260  {'base_withdrawal_fee': '0.000000000000000000'...
# 261  {'base_withdrawal_fee': '0.000000000000000000'...
# 262  {'base_withdrawal_fee': '0.000000000000000000'...
# 263  {'base_withdrawal_fee': '0.000000000000000000'...
# 264  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                       underlying_asset trading_status  \
# 4    {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 5    {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 94   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 95   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 100  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# ..                                                 ...            ...
# 260  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 261  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 262  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 263  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 264  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#     liquidation_penalty_factor  impact_size state  ... strike_price  \
# 4                          0.5          200  live  ...       116600
# 5                          0.5          200  live  ...       116600
# 94                         0.5          200  live  ...       112200
# 95                         0.5          200  live  ...       112200
# 100                        0.5          200  live  ...       110000
# ..                         ...          ...   ...  ...          ...
# 260                        0.5          200  live  ...       114600
# 261                        0.5          200  live  ...       114800
# 262                        0.5          200  live  ...       115000
# 263                        0.5          200  live  ...       115200
# 264                        0.5          200  live  ...       115400
#
#                   symbol short_description  \
# 4    C-BTC-116600-070825         BTC  Call
# 5    P-BTC-116600-070825          BTC  Put
# 94   C-BTC-112200-070825         BTC  Call
# 95   P-BTC-112200-070825          BTC  Put
# 100  C-BTC-110000-070825         BTC  Call
# ..                   ...               ...
# 260  P-BTC-114600-070825          BTC  Put
# 261  P-BTC-114800-070825          BTC  Put
# 262  P-BTC-115000-070825          BTC  Put
# 263  P-BTC-115200-070825          BTC  Put
# 264  P-BTC-115400-070825          BTC  Put
#
#                                             spot_index  \
# 4    {'config': {'price_alert_enabled': True, 'quot...
# 5    {'config': {'price_alert_enabled': True, 'quot...
# 94   {'config': {'price_alert_enabled': True, 'quot...
# 95   {'config': {'price_alert_enabled': True, 'quot...
# 100  {'config': {'price_alert_enabled': True, 'quot...
# ..                                                 ...
# 260  {'config': {'price_alert_enabled': True, 'quot...
# 261  {'config': {'price_alert_enabled': True, 'quot...
# 262  {'config': {'price_alert_enabled': True, 'quot...
# 263  {'config': {'price_alert_enabled': True, 'quot...
# 264  {'config': {'price_alert_enabled': True, 'quot...
#
#                                          product_specs taker_commission_rate  \
# 4    {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 5    {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 94   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 95   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 100  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# ..                                                 ...                   ...
# 260  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 261  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 262  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 263  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 264  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                               description  initial_margin  \
# 4    BTC call option expiring on 7-8-2025             0.5
# 5     BTC put option expiring on 7-8-2025             0.5
# 94   BTC call option expiring on 7-8-2025             0.5
# 95    BTC put option expiring on 7-8-2025             0.5
# 100  BTC call option expiring on 7-8-2025             0.5
# ..                                    ...             ...
# 260   BTC put option expiring on 7-8-2025             0.5
# 261   BTC put option expiring on 7-8-2025             0.5
# 262   BTC put option expiring on 7-8-2025             0.5
# 263   BTC put option expiring on 7-8-2025             0.5
# 264   BTC put option expiring on 7-8-2025             0.5
#
#     initial_margin_scaling_factor      expiry
# 4                        0.000002  2025-08-07
# 5                        0.000002  2025-08-07
# 94                       0.000002  2025-08-07
# 95                       0.000002  2025-08-07
# 100                      0.000002  2025-08-07
# ..                            ...         ...
# 260                      0.000002  2025-08-07
# 261                      0.000002  2025-08-07
# 262                      0.000002  2025-08-07
# 263                      0.000002  2025-08-07
# 264                      0.000002  2025-08-07
#
# [67 rows x 43 columns]

# %%
btcdf.contract_type.unique()
# Out:
# array(['call_options', 'put_options'], dtype=object)

# %%
btcdf[btcdf.contract_type == 'call_options']
# Out:
#     maker_commission_rate disruption_reason  \
# 4                 0.00015              None
# 94                0.00015              None
# 100               0.00015              None
# 103               0.00015              None
# 108               0.00015              None
# 114               0.00015              None
# 173               0.00015              None
# 175               0.00015              None
# 181               0.00015              None
# 185               0.00015              None
# 187               0.00015              None
# 191               0.00015              None
# 196               0.00015              None
# 197               0.00015              None
# 198               0.00015              None
# 199               0.00015              None
# 200               0.00015              None
# 201               0.00015              None
# 213               0.00015              None
# 214               0.00015              None
# 215               0.00015              None
# 216               0.00015              None
# 217               0.00015              None
# 218               0.00015              None
# 245               0.00015              None
# 246               0.00015              None
# 247               0.00015              None
# 248               0.00015              None
# 249               0.00015              None
# 250               0.00015              None
# 251               0.00015              None
# 252               0.00015              None
# 253               0.00015              None
# 254               0.00015              None
#
#     insurance_fund_margin_contribution           settlement_time  \
# 4                                    5 2025-08-07 12:00:00+00:00
# 94                                   5 2025-08-07 12:00:00+00:00
# 100                                  5 2025-08-07 12:00:00+00:00
# 103                                  5 2025-08-07 12:00:00+00:00
# 108                                  5 2025-08-07 12:00:00+00:00
# 114                                  5 2025-08-07 12:00:00+00:00
# 173                                  5 2025-08-07 12:00:00+00:00
# 175                                  5 2025-08-07 12:00:00+00:00
# 181                                  5 2025-08-07 12:00:00+00:00
# 185                                  5 2025-08-07 12:00:00+00:00
# 187                                  5 2025-08-07 12:00:00+00:00
# 191                                  5 2025-08-07 12:00:00+00:00
# 196                                  5 2025-08-07 12:00:00+00:00
# 197                                  5 2025-08-07 12:00:00+00:00
# 198                                  5 2025-08-07 12:00:00+00:00
# 199                                  5 2025-08-07 12:00:00+00:00
# 200                                  5 2025-08-07 12:00:00+00:00
# 201                                  5 2025-08-07 12:00:00+00:00
# 213                                  5 2025-08-07 12:00:00+00:00
# 214                                  5 2025-08-07 12:00:00+00:00
# 215                                  5 2025-08-07 12:00:00+00:00
# 216                                  5 2025-08-07 12:00:00+00:00
# 217                                  5 2025-08-07 12:00:00+00:00
# 218                                  5 2025-08-07 12:00:00+00:00
# 245                                  5 2025-08-07 12:00:00+00:00
# 246                                  5 2025-08-07 12:00:00+00:00
# 247                                  5 2025-08-07 12:00:00+00:00
# 248                                  5 2025-08-07 12:00:00+00:00
# 249                                  5 2025-08-07 12:00:00+00:00
# 250                                  5 2025-08-07 12:00:00+00:00
# 251                                  5 2025-08-07 12:00:00+00:00
# 252                                  5 2025-08-07 12:00:00+00:00
# 253                                  5 2025-08-07 12:00:00+00:00
# 254                                  5 2025-08-07 12:00:00+00:00
#
#                                          quoting_asset  \
# 4    {'base_withdrawal_fee': '0.000000000000000000'...
# 94   {'base_withdrawal_fee': '0.000000000000000000'...
# 100  {'base_withdrawal_fee': '0.000000000000000000'...
# 103  {'base_withdrawal_fee': '0.000000000000000000'...
# 108  {'base_withdrawal_fee': '0.000000000000000000'...
# 114  {'base_withdrawal_fee': '0.000000000000000000'...
# 173  {'base_withdrawal_fee': '0.000000000000000000'...
# 175  {'base_withdrawal_fee': '0.000000000000000000'...
# 181  {'base_withdrawal_fee': '0.000000000000000000'...
# 185  {'base_withdrawal_fee': '0.000000000000000000'...
# 187  {'base_withdrawal_fee': '0.000000000000000000'...
# 191  {'base_withdrawal_fee': '0.000000000000000000'...
# 196  {'base_withdrawal_fee': '0.000000000000000000'...
# 197  {'base_withdrawal_fee': '0.000000000000000000'...
# 198  {'base_withdrawal_fee': '0.000000000000000000'...
# 199  {'base_withdrawal_fee': '0.000000000000000000'...
# 200  {'base_withdrawal_fee': '0.000000000000000000'...
# 201  {'base_withdrawal_fee': '0.000000000000000000'...
# 213  {'base_withdrawal_fee': '0.000000000000000000'...
# 214  {'base_withdrawal_fee': '0.000000000000000000'...
# 215  {'base_withdrawal_fee': '0.000000000000000000'...
# 216  {'base_withdrawal_fee': '0.000000000000000000'...
# 217  {'base_withdrawal_fee': '0.000000000000000000'...
# 218  {'base_withdrawal_fee': '0.000000000000000000'...
# 245  {'base_withdrawal_fee': '0.000000000000000000'...
# 246  {'base_withdrawal_fee': '0.000000000000000000'...
# 247  {'base_withdrawal_fee': '0.000000000000000000'...
# 248  {'base_withdrawal_fee': '0.000000000000000000'...
# 249  {'base_withdrawal_fee': '0.000000000000000000'...
# 250  {'base_withdrawal_fee': '0.000000000000000000'...
# 251  {'base_withdrawal_fee': '0.000000000000000000'...
# 252  {'base_withdrawal_fee': '0.000000000000000000'...
# 253  {'base_withdrawal_fee': '0.000000000000000000'...
# 254  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                       underlying_asset trading_status  \
# 4    {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 94   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 100  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 103  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 108  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 114  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 173  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 175  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 181  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 185  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 187  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 191  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 196  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 197  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 198  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 199  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 200  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 201  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 213  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 214  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 215  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 216  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 217  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 218  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 245  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 246  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 247  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 248  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 249  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 250  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 251  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 252  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 253  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 254  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#     liquidation_penalty_factor  impact_size state  ... strike_price  \
# 4                          0.5          200  live  ...       116600
# 94                         0.5          200  live  ...       112200
# 100                        0.5          200  live  ...       110000
# 103                        0.5          200  live  ...       112600
# 108                        0.5          200  live  ...       110400
# 114                        0.5          200  live  ...       113000
# 173                        0.5          200  live  ...       116200
# 175                        0.5          200  live  ...       115800
# 181                        0.5          200  live  ...       118400
# 185                        0.5          200  live  ...       118000
# 187                        0.5          200  live  ...       110800
# 191                        0.5          200  live  ...       113400
# 196                        0.5          200  live  ...       117600
# 197                        0.5          200  live  ...       117200
# 198                        0.5          200  live  ...       116800
# 199                        0.5          200  live  ...       111200
# 200                        0.5          200  live  ...       111600
# 201                        0.5          200  live  ...       112000
# 213                        0.5          200  live  ...       116400
# 214                        0.5          200  live  ...       116000
# 215                        0.5          200  live  ...       115600
# 216                        0.5          200  live  ...       112400
# 217                        0.5          200  live  ...       112800
# 218                        0.5          200  live  ...       113200
# 245                        0.5          200  live  ...       113600
# 246                        0.5          200  live  ...       113800
# 247                        0.5          200  live  ...       114000
# 248                        0.5          200  live  ...       114200
# 249                        0.5          200  live  ...       114400
# 250                        0.5          200  live  ...       114600
# 251                        0.5          200  live  ...       114800
# 252                        0.5          200  live  ...       115000
# 253                        0.5          200  live  ...       115200
# 254                        0.5          200  live  ...       115400
#
#                   symbol short_description  \
# 4    C-BTC-116600-070825         BTC  Call
# 94   C-BTC-112200-070825         BTC  Call
# 100  C-BTC-110000-070825         BTC  Call
# 103  C-BTC-112600-070825         BTC  Call
# 108  C-BTC-110400-070825         BTC  Call
# 114  C-BTC-113000-070825         BTC  Call
# 173  C-BTC-116200-070825         BTC  Call
# 175  C-BTC-115800-070825         BTC  Call
# 181  C-BTC-118400-070825         BTC  Call
# 185  C-BTC-118000-070825         BTC  Call
# 187  C-BTC-110800-070825         BTC  Call
# 191  C-BTC-113400-070825         BTC  Call
# 196  C-BTC-117600-070825         BTC  Call
# 197  C-BTC-117200-070825         BTC  Call
# 198  C-BTC-116800-070825         BTC  Call
# 199  C-BTC-111200-070825         BTC  Call
# 200  C-BTC-111600-070825         BTC  Call
# 201  C-BTC-112000-070825         BTC  Call
# 213  C-BTC-116400-070825         BTC  Call
# 214  C-BTC-116000-070825         BTC  Call
# 215  C-BTC-115600-070825         BTC  Call
# 216  C-BTC-112400-070825         BTC  Call
# 217  C-BTC-112800-070825         BTC  Call
# 218  C-BTC-113200-070825         BTC  Call
# 245  C-BTC-113600-070825         BTC  Call
# 246  C-BTC-113800-070825         BTC  Call
# 247  C-BTC-114000-070825         BTC  Call
# 248  C-BTC-114200-070825         BTC  Call
# 249  C-BTC-114400-070825         BTC  Call
# 250  C-BTC-114600-070825         BTC  Call
# 251  C-BTC-114800-070825         BTC  Call
# 252  C-BTC-115000-070825         BTC  Call
# 253  C-BTC-115200-070825         BTC  Call
# 254  C-BTC-115400-070825         BTC  Call
#
#                                             spot_index  \
# 4    {'config': {'price_alert_enabled': True, 'quot...
# 94   {'config': {'price_alert_enabled': True, 'quot...
# 100  {'config': {'price_alert_enabled': True, 'quot...
# 103  {'config': {'price_alert_enabled': True, 'quot...
# 108  {'config': {'price_alert_enabled': True, 'quot...
# 114  {'config': {'price_alert_enabled': True, 'quot...
# 173  {'config': {'price_alert_enabled': True, 'quot...
# 175  {'config': {'price_alert_enabled': True, 'quot...
# 181  {'config': {'price_alert_enabled': True, 'quot...
# 185  {'config': {'price_alert_enabled': True, 'quot...
# 187  {'config': {'price_alert_enabled': True, 'quot...
# 191  {'config': {'price_alert_enabled': True, 'quot...
# 196  {'config': {'price_alert_enabled': True, 'quot...
# 197  {'config': {'price_alert_enabled': True, 'quot...
# 198  {'config': {'price_alert_enabled': True, 'quot...
# 199  {'config': {'price_alert_enabled': True, 'quot...
# 200  {'config': {'price_alert_enabled': True, 'quot...
# 201  {'config': {'price_alert_enabled': True, 'quot...
# 213  {'config': {'price_alert_enabled': True, 'quot...
# 214  {'config': {'price_alert_enabled': True, 'quot...
# 215  {'config': {'price_alert_enabled': True, 'quot...
# 216  {'config': {'price_alert_enabled': True, 'quot...
# 217  {'config': {'price_alert_enabled': True, 'quot...
# 218  {'config': {'price_alert_enabled': True, 'quot...
# 245  {'config': {'price_alert_enabled': True, 'quot...
# 246  {'config': {'price_alert_enabled': True, 'quot...
# 247  {'config': {'price_alert_enabled': True, 'quot...
# 248  {'config': {'price_alert_enabled': True, 'quot...
# 249  {'config': {'price_alert_enabled': True, 'quot...
# 250  {'config': {'price_alert_enabled': True, 'quot...
# 251  {'config': {'price_alert_enabled': True, 'quot...
# 252  {'config': {'price_alert_enabled': True, 'quot...
# 253  {'config': {'price_alert_enabled': True, 'quot...
# 254  {'config': {'price_alert_enabled': True, 'quot...
#
#                                          product_specs taker_commission_rate  \
# 4    {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 94   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 100  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 103  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 108  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 114  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 173  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 175  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 181  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 185  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 187  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 191  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 196  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 197  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 198  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 199  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 200  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 201  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 213  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 214  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 215  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 216  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 217  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 218  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 245  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 246  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 247  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 248  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 249  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 250  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 251  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 252  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 253  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 254  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                               description  initial_margin  \
# 4    BTC call option expiring on 7-8-2025             0.5
# 94   BTC call option expiring on 7-8-2025             0.5
# 100  BTC call option expiring on 7-8-2025             0.5
# 103  BTC call option expiring on 7-8-2025             0.5
# 108  BTC call option expiring on 7-8-2025             0.5
# 114  BTC call option expiring on 7-8-2025             0.5
# 173  BTC call option expiring on 7-8-2025             0.5
# 175  BTC call option expiring on 7-8-2025             0.5
# 181  BTC call option expiring on 7-8-2025             0.5
# 185  BTC call option expiring on 7-8-2025             0.5
# 187  BTC call option expiring on 7-8-2025             0.5
# 191  BTC call option expiring on 7-8-2025             0.5
# 196  BTC call option expiring on 7-8-2025             0.5
# 197  BTC call option expiring on 7-8-2025             0.5
# 198  BTC call option expiring on 7-8-2025             0.5
# 199  BTC call option expiring on 7-8-2025             0.5
# 200  BTC call option expiring on 7-8-2025             0.5
# 201  BTC call option expiring on 7-8-2025             0.5
# 213  BTC call option expiring on 7-8-2025             0.5
# 214  BTC call option expiring on 7-8-2025             0.5
# 215  BTC call option expiring on 7-8-2025             0.5
# 216  BTC call option expiring on 7-8-2025             0.5
# 217  BTC call option expiring on 7-8-2025             0.5
# 218  BTC call option expiring on 7-8-2025             0.5
# 245  BTC call option expiring on 7-8-2025             0.5
# 246  BTC call option expiring on 7-8-2025             0.5
# 247  BTC call option expiring on 7-8-2025             0.5
# 248  BTC call option expiring on 7-8-2025             0.5
# 249  BTC call option expiring on 7-8-2025             0.5
# 250  BTC call option expiring on 7-8-2025             0.5
# 251  BTC call option expiring on 7-8-2025             0.5
# 252  BTC call option expiring on 7-8-2025             0.5
# 253  BTC call option expiring on 7-8-2025             0.5
# 254  BTC call option expiring on 7-8-2025             0.5
#
#     initial_margin_scaling_factor      expiry
# 4                        0.000002  2025-08-07
# 94                       0.000002  2025-08-07
# 100                      0.000002  2025-08-07
# 103                      0.000002  2025-08-07
# 108                      0.000002  2025-08-07
# 114                      0.000002  2025-08-07
# 173                      0.000002  2025-08-07
# 175                      0.000002  2025-08-07
# 181                      0.000002  2025-08-07
# 185                      0.000002  2025-08-07
# 187                      0.000002  2025-08-07
# 191                      0.000002  2025-08-07
# 196                      0.000002  2025-08-07
# 197                      0.000002  2025-08-07
# 198                      0.000002  2025-08-07
# 199                      0.000002  2025-08-07
# 200                      0.000002  2025-08-07
# 201                      0.000002  2025-08-07
# 213                      0.000002  2025-08-07
# 214                      0.000002  2025-08-07
# 215                      0.000002  2025-08-07
# 216                      0.000002  2025-08-07
# 217                      0.000002  2025-08-07
# 218                      0.000002  2025-08-07
# 245                      0.000002  2025-08-07
# 246                      0.000002  2025-08-07
# 247                      0.000002  2025-08-07
# 248                      0.000002  2025-08-07
# 249                      0.000002  2025-08-07
# 250                      0.000002  2025-08-07
# 251                      0.000002  2025-08-07
# 252                      0.000002  2025-08-07
# 253                      0.000002  2025-08-07
# 254                      0.000002  2025-08-07
#
# [34 rows x 43 columns]

# %%
btcdf_calloption=btcdf[btcdf.contract_type == 'call_options']

# %%
btcdf_calloption.head()
# Out:
#     maker_commission_rate disruption_reason  \
# 4                 0.00015              None
# 94                0.00015              None
# 100               0.00015              None
# 103               0.00015              None
# 108               0.00015              None
#
#     insurance_fund_margin_contribution           settlement_time  \
# 4                                    5 2025-08-07 12:00:00+00:00
# 94                                   5 2025-08-07 12:00:00+00:00
# 100                                  5 2025-08-07 12:00:00+00:00
# 103                                  5 2025-08-07 12:00:00+00:00
# 108                                  5 2025-08-07 12:00:00+00:00
#
#                                          quoting_asset  \
# 4    {'base_withdrawal_fee': '0.000000000000000000'...
# 94   {'base_withdrawal_fee': '0.000000000000000000'...
# 100  {'base_withdrawal_fee': '0.000000000000000000'...
# 103  {'base_withdrawal_fee': '0.000000000000000000'...
# 108  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                       underlying_asset trading_status  \
# 4    {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 94   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 100  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 103  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 108  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#     liquidation_penalty_factor  impact_size state  ... strike_price  \
# 4                          0.5          200  live  ...       116600
# 94                         0.5          200  live  ...       112200
# 100                        0.5          200  live  ...       110000
# 103                        0.5          200  live  ...       112600
# 108                        0.5          200  live  ...       110400
#
#                   symbol short_description  \
# 4    C-BTC-116600-070825         BTC  Call
# 94   C-BTC-112200-070825         BTC  Call
# 100  C-BTC-110000-070825         BTC  Call
# 103  C-BTC-112600-070825         BTC  Call
# 108  C-BTC-110400-070825         BTC  Call
#
#                                             spot_index  \
# 4    {'config': {'price_alert_enabled': True, 'quot...
# 94   {'config': {'price_alert_enabled': True, 'quot...
# 100  {'config': {'price_alert_enabled': True, 'quot...
# 103  {'config': {'price_alert_enabled': True, 'quot...
# 108  {'config': {'price_alert_enabled': True, 'quot...
#
#                                          product_specs taker_commission_rate  \
# 4    {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 94   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 100  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 103  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 108  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                               description  initial_margin  \
# 4    BTC call option expiring on 7-8-2025             0.5
# 94   BTC call option expiring on 7-8-2025             0.5
# 100  BTC call option expiring on 7-8-2025             0.5
# 103  BTC call option expiring on 7-8-2025             0.5
# 108  BTC call option expiring on 7-8-2025             0.5
#
#     initial_margin_scaling_factor      expiry
# 4                        0.000002  2025-08-07
# 94                       0.000002  2025-08-07
# 100                      0.000002  2025-08-07
# 103                      0.000002  2025-08-07
# 108                      0.000002  2025-08-07
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Get product by ID

# %%
delta_client.get_product('63146')
# Out:
# {'price_band': '2',
#  'underlying_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 12,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 4,
#   'name': 'Ethereum',
#   'networks': [],
#   'precision': 18,
#   'sort_priority': 2,
#   'symbol': 'ETH',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'insurance_fund_margin_contribution': '1',
#  'ui_config': {'default_trading_view_candle': '15',
#   'leverage_slider_values': [1, 2, 5, 10, 20, 50, 100],
#   'price_clubbing_values': [0.01, 0.05, 0.1, 0.5, 1, 2.5, 5],
#   'show_bracket_orders': False,
#   'sort_priority': 1,
#   'tags': []},
#  'product_specs': {'backup_vol_expiry_time': 31536000,
#   'max_deviation_from_external_vol': 0.75,
#   'max_lower_deviation_from_external_vol': 0.75,
#   'max_upper_deviation_from_external_vol': 0.5,
#   'max_volatility': 3,
#   'min_volatility': 0.1,
#   'only_reduce_only_orders_allowed': False,
#   'premium_commission_rate': 0.1,
#   'settlement_index_price': '2408.1751724137926',
#   'vol_calculation_method': 'orderbook',
#   'vol_expiry_time': 31536000},
#  'symbol': 'C-ETH-2860-250225',
#  'position_size_limit': 173467,
#  'settlement_price': '0',
#  'state': 'expired',
#  'tick_size': '0.01',
#  'funding_method': 'mark_price',
#  'maintenance_margin': '0.5',
#  'spot_index': {'config': {'price_alert_enabled': True,
#    'quoting_asset': 'USD',
#    'service_id': 1,
#    'underlying_asset': 'ETH'},
#   'constituent_exchanges': [],
#   'constituent_indices': {'expression': '${e1} * ${e2}',
#    'indices': {'e1': '.DEETHUSDT', 'e2': '.DEUSDTUSD'}},
#   'description': 'ETH spot price index quoted in US Dollar',
#   'health_interval': 300,
#   'id': 17,
#   'impact_size': '4.000000000000000000',
#   'index_type': 'spot_pair',
#   'is_composite': True,
#   'price_method': 'orderbook',
#   'quoting_asset_id': 14,
#   'symbol': '.DEETHUSD',
#   'tick_size': '0.010000000000000000',
#   'underlying_asset_id': 12},
#  'id': 63146,
#  'short_description': 'ETH  Call',
#  'trading_status': 'operational',
#  'notional_type': 'vanilla',
#  'launch_time': '2025-02-22T16:05:09Z',
#  'barrier_price': None,
#  'strike_price': '2860',
#  'initial_margin': '1',
#  'liquidation_penalty_factor': '0.5',
#  'is_quanto': False,
#  'contract_value': '0.01',
#  'impact_size': 300,
#  'auction_finish_time': None,
#  'maker_commission_rate': '0.0003',
#  'taker_commission_rate': '0.0003',
#  'annualized_funding': '10.95',
#  'quoting_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'default_leverage': '100.000000000000000000',
#  'settlement_time': '2025-02-25T12:00:00Z',
#  'contract_unit_currency': 'ETH',
#  'maintenance_margin_scaling_factor': '0.000002',
#  'disruption_reason': None,
#  'contract_type': 'call_options',
#  'max_leverage_notional': '100000',
#  'basis_factor_max_limit': '10.95',
#  'initial_margin_scaling_factor': '0.000004',
#  'settling_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'description': 'ETH call option expiring on 25-2-2025',
#  'auction_start_time': '2025-02-22T16:05:09Z'}

# %%
delta_client.get_product('C-ETH-3740-050825')
# Out:
# {'maker_commission_rate': '0.00015',
#  'disruption_reason': None,
#  'insurance_fund_margin_contribution': '5',
#  'settlement_time': '2025-08-05T12:00:00Z',
#  'quoting_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'underlying_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 12,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 4,
#   'name': 'Ethereum',
#   'networks': [],
#   'precision': 18,
#   'sort_priority': 2,
#   'symbol': 'ETH',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'trading_status': 'operational',
#  'liquidation_penalty_factor': '0.5',
#  'impact_size': 300,
#  'state': 'expired',
#  'settling_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'id': 88229,
#  'tick_size': '0.01',
#  'barrier_price': None,
#  'auction_finish_time': None,
#  'annualized_funding': '10.95',
#  'funding_method': 'mark_price',
#  'is_quanto': False,
#  'max_leverage_notional': '100000',
#  'launch_time': '2025-08-04T14:25:14Z',
#  'contract_unit_currency': 'ETH',
#  'contract_type': 'call_options',
#  'maintenance_margin': '0.5',
#  'basis_factor_max_limit': '10.95',
#  'notional_type': 'vanilla',
#  'price_band': '2',
#  'position_size_limit': 173467,
#  'settlement_price': '0',
#  'contract_value': '0.01',
#  'maintenance_margin_scaling_factor': '0.000002',
#  'ui_config': {'default_trading_view_candle': '15',
#   'leverage_slider_values': [1, 2, 5, 10, 20, 50, 100],
#   'price_clubbing_values': [0.01, 0.05, 0.1, 0.5, 1, 2.5, 5],
#   'show_bracket_orders': False,
#   'sort_priority': 1,
#   'tags': []},
#  'default_leverage': '100.000000000000000000',
#  'auction_start_time': '2025-08-04T14:25:14Z',
#  'strike_price': '3740',
#  'symbol': 'C-ETH-3740-050825',
#  'short_description': 'ETH  Call',
#  'spot_index': {'config': {'price_alert_enabled': True,
#    'quoting_asset': 'USD',
#    'service_id': 1,
#    'underlying_asset': 'ETH'},
#   'constituent_exchanges': [],
#   'constituent_indices': {'expression': '${e1} * ${e2}',
#    'indices': {'e1': '.DEETHUSDT', 'e2': '.DEUSDTUSD'}},
#   'description': 'ETH spot price index quoted in US Dollar',
#   'health_interval': 300,
#   'id': 17,
#   'impact_size': '4.000000000000000000',
#   'index_type': 'spot_pair',
#   'is_composite': True,
#   'price_method': 'orderbook',
#   'quoting_asset_id': 14,
#   'symbol': '.DEETHUSD',
#   'tick_size': '0.010000000000000000',
#   'underlying_asset_id': 12},
#  'product_specs': {'backup_vol_expiry_time': 31536000,
#   'isolated_liq_penalty_factor': 0.001,
#   'isolated_liq_premium_penalty_factor': 0.2,
#   'max_deviation_from_external_vol': 0.75,
#   'max_lower_deviation_from_external_vol': 0.75,
#   'max_upper_deviation_from_external_vol': 0.5,
#   'max_volatility': 3,
#   'min_volatility': 0.1,
#   'only_reduce_only_orders_allowed': False,
#   'premium_commission_rate': 0.1,
#   'settlement_index_price': '3672.564827586208',
#   'vol_calculation_method': 'orderbook',
#   'vol_expiry_time': 31536000},
#  'taker_commission_rate': '0.00015',
#  'description': 'ETH call option expiring on 5-8-2025',
#  'initial_margin': '1',
#  'initial_margin_scaling_factor': '0.000004'}

# %%
ethdf = symdf[(symdf.expiry ==expiryDate.date() )& (symdf.contract_unit_currency == 'ETH') ]

# %%
ethdf.head()
# Out:
#     maker_commission_rate disruption_reason  \
# 160               0.00015              None
# 161               0.00015              None
# 162               0.00015              None
# 165               0.00015              None
# 166               0.00015              None
#
#     insurance_fund_margin_contribution           settlement_time  \
# 160                                  5 2025-08-07 12:00:00+00:00
# 161                                  5 2025-08-07 12:00:00+00:00
# 162                                  5 2025-08-07 12:00:00+00:00
# 165                                  5 2025-08-07 12:00:00+00:00
# 166                                  5 2025-08-07 12:00:00+00:00
#
#                                          quoting_asset  \
# 160  {'base_withdrawal_fee': '0.000000000000000000'...
# 161  {'base_withdrawal_fee': '0.000000000000000000'...
# 162  {'base_withdrawal_fee': '0.000000000000000000'...
# 165  {'base_withdrawal_fee': '0.000000000000000000'...
# 166  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                       underlying_asset trading_status  \
# 160  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 161  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 162  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 165  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 166  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#     liquidation_penalty_factor  impact_size state  ... strike_price  \
# 160                        0.5          300  live  ...         3820
# 161                        0.5          300  live  ...         3820
# 162                        0.5          300  live  ...         3920
# 165                        0.5          300  live  ...         3920
# 166                        0.5          300  live  ...         3780
#
#                 symbol short_description  \
# 160  C-ETH-3820-070825         ETH  Call
# 161  P-ETH-3820-070825          ETH  Put
# 162  P-ETH-3920-070825          ETH  Put
# 165  C-ETH-3920-070825         ETH  Call
# 166  C-ETH-3780-070825         ETH  Call
#
#                                             spot_index  \
# 160  {'config': {'price_alert_enabled': True, 'quot...
# 161  {'config': {'price_alert_enabled': True, 'quot...
# 162  {'config': {'price_alert_enabled': True, 'quot...
# 165  {'config': {'price_alert_enabled': True, 'quot...
# 166  {'config': {'price_alert_enabled': True, 'quot...
#
#                                          product_specs taker_commission_rate  \
# 160  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 161  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 162  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 165  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 166  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                               description  initial_margin  \
# 160  ETH call option expiring on 7-8-2025               1
# 161   ETH put option expiring on 7-8-2025               1
# 162   ETH put option expiring on 7-8-2025               1
# 165  ETH call option expiring on 7-8-2025               1
# 166  ETH call option expiring on 7-8-2025               1
#
#     initial_margin_scaling_factor      expiry
# 160                      0.000004  2025-08-07
# 161                      0.000004  2025-08-07
# 162                      0.000004  2025-08-07
# 165                      0.000004  2025-08-07
# 166                      0.000004  2025-08-07
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Get Ticker

# %%
# Get Ticker
delta_client.get_ticker('BTCUSD')

# %%
delta_client.get_ticker('C-BTC-91600-240225')

# %%
tickRes = delta_client.get_ticker('')
tickDf = pd.DataFrame(tickRes)
tickDf

# %%
tickRes = delta_client.get_ticker('?contract_types=put_options')
tickDf = pd.DataFrame(tickRes)
tickDf

# %%
import requests
headers = {
  'Accept': 'application/json'
}

r = requests.get('https://api.india.delta.exchange/v2/indices', params={

}, headers = headers)

r.json()

# %% [markdown]
# ## Filter ATM Strike

# %%
tickRes = delta_client.get_ticker('BTCUSD')
tickRes

tickRes['spot_price']

spotPrice = float(tickRes['spot_price'])
spotPrice

atmStrike = round(float(spotPrice)/200)*200

atmStrike



expDate = datetime.now() + timedelta(days= 1)
expDate



expStr = expDate.strftime("%d%m%y")
expStr


callSym  = f'C-BTC-{atmStrike}-{expStr}'
callSym


putSym  = f'P-BTC-{atmStrike}-{expStr}'
putSym


delta_client.get_product(putSym)


delta_client.get_product(callSym)
