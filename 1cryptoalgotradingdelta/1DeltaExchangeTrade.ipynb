# %%
pip install delta-rest-client
# Out:
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# Requirement already satisfied: delta-rest-client in /opt/anaconda3/lib/python3.12/site-packages (1.0.12)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Symbol Management / Ticker /Filter Options Strike

# %%
import os
from dotenv import load_dotenv
load_dotenv()

apikey=os.getenv('DELTA_API_KEY')
apiSecret=os.getenv('DELTA_API_SECRET')

# %%
from delta_rest_client import DeltaRestClient
import pandas as pd
from datetime import datetime , timedelta

delta_client = DeltaRestClient(
  base_url='https://api.india.delta.exchange',
  api_key=apikey,
  api_secret=apiSecret
)
delta_client

# %% [markdown]
# ## Get Master List

# %%
# Get symbol list
res = delta_client.get_product('')
symdf = pd.DataFrame(res)
symdf
# Out:
#      maker_commission_rate disruption_reason  \
# 0                  0.00015              None
# 1                  0.00015              None
# 2                  0.00015              None
# 3                  0.00015              None
# 4                  0.00015              None
# ...                    ...               ...
# 1068                0.0002              None
# 1069                0.0002              None
# 1070                0.0002              None
# 1071                0.0002              None
# 1072                0.0002              None
#
#      insurance_fund_margin_contribution       settlement_time  \
# 0                                     5  2025-08-10T12:00:00Z
# 1                                     5  2025-08-10T12:00:00Z
# 2                                     5  2025-08-10T12:00:00Z
# 3                                     5  2025-08-09T12:00:00Z
# 4                                     5  2025-08-09T12:00:00Z
# ...                                 ...                   ...
# 1068                                  5                  None
# 1069                                  5                  None
# 1070                                  5                  None
# 1071                                  5                  None
# 1072                                  5                  None
#
#                                           quoting_asset  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...
# 1     {'base_withdrawal_fee': '0.000000000000000000'...
# 2     {'base_withdrawal_fee': '0.000000000000000000'...
# 3     {'base_withdrawal_fee': '0.000000000000000000'...
# 4     {'base_withdrawal_fee': '0.000000000000000000'...
# ...                                                 ...
# 1068  {'base_withdrawal_fee': '0.000000000000000000'...
# 1069  {'base_withdrawal_fee': '0.000000000000000000'...
# 1070  {'base_withdrawal_fee': '0.000000000000000000'...
# 1071  {'base_withdrawal_fee': '0.000000000000000000'...
# 1072  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                        underlying_asset trading_status  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 2     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 3     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 4     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# ...                                                 ...            ...
# 1068  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1069  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1070  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1071  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1072  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#      liquidation_penalty_factor  impact_size state  ...    auction_start_time  \
# 0                           0.5          200  live  ...  2025-08-07T13:40:09Z
# 1                           0.5          300  live  ...  2025-08-07T13:00:15Z
# 2                           0.5          300  live  ...  2025-08-07T13:00:15Z
# 3                           0.5          300  live  ...  2025-08-07T13:00:14Z
# 4                           0.5          300  live  ...  2025-08-07T13:00:14Z
# ...                         ...          ...   ...  ...                   ...
# 1068                        0.2         2469  live  ...  2025-07-27T05:47:40Z
# 1069                        0.2         1500  live  ...  2025-07-27T05:47:41Z
# 1070                        0.2         5282  live  ...  2025-07-27T05:47:41Z
# 1071                        0.2         9591  live  ...  2025-07-27T05:47:40Z
# 1072                        0.5        10000  live  ...  2025-07-27T05:47:41Z
#
#       strike_price               symbol    short_description  \
# 0           119200  P-BTC-119200-100825             BTC  Put
# 1             3940    C-ETH-3940-100825            ETH  Call
# 2             3940    P-ETH-3940-100825             ETH  Put
# 3             3940    C-ETH-3940-090825            ETH  Call
# 4             4040    P-ETH-4040-090825             ETH  Put
# ...            ...                  ...                  ...
# 1068          None              AVAXUSD  Avalanche Perpetual
# 1069          None               SOLUSD     Solana Perpetual
# 1070          None              DOGEUSD   Dogecoin Perpetual
# 1071          None               ETHUSD   Ethereum Perpetual
# 1072          None               BTCUSD    Bitcoin Perpetual
#
#                                              spot_index  \
# 0     {'config': {'price_alert_enabled': True, 'quot...
# 1     {'config': {'price_alert_enabled': True, 'quot...
# 2     {'config': {'price_alert_enabled': True, 'quot...
# 3     {'config': {'price_alert_enabled': True, 'quot...
# 4     {'config': {'price_alert_enabled': True, 'quot...
# ...                                                 ...
# 1068  {'config': {'price_alert_enabled': True, 'quot...
# 1069  {'config': {'price_alert_enabled': True, 'quot...
# 1070  {'config': {'price_alert_enabled': True, 'quot...
# 1071  {'config': {'price_alert_enabled': True, 'quot...
# 1072  {'config': {'price_alert_enabled': True, 'quot...
#
#                                           product_specs taker_commission_rate  \
# 0     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 1     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 2     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 3     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 4     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# ...                                                 ...                   ...
# 1068  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1069  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1070  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1071  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1072  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
#
#                                             description initial_margin  \
# 0                  BTC put option expiring on 10-8-2025              1
# 1                 ETH call option expiring on 10-8-2025              1
# 2                  ETH put option expiring on 10-8-2025              1
# 3                  ETH call option expiring on 9-8-2025              1
# 4                   ETH put option expiring on 9-8-2025              1
# ...                                                 ...            ...
# 1068            Avalance perpetual future quoted in USD              1
# 1069              Solana perpetual future quoted in USD              1
# 1070            Dogecoin perpetual future quoted in USD              1
# 1071  Ethereum Perpetual futures, quoted, settled & ...            0.5
# 1072  Bitcoin Perpetual futures, quoted, settled & m...            0.5
#
#      initial_margin_scaling_factor
# 0                         0.000002
# 1                         0.000004
# 2                         0.000004
# 3                         0.000004
# 4                         0.000004
# ...                            ...
# 1068                      0.000004
# 1069                      0.000004
# 1070                      0.000004
# 1071                      0.000004
# 1072                     0.0000025
#
# [1073 rows x 42 columns]

# %%
symdf.contract_type.unique()
# Out:
# array(['put_options', 'call_options', 'perpetual_futures', 'tracker'],
#       dtype=object)

# %%
symdf.iloc[0]
# Out:
# maker_commission_rate                                                           0.00015
# disruption_reason                                                                  None
# insurance_fund_margin_contribution                                                    5
# settlement_time                                                    2025-08-10T12:00:00Z
# quoting_asset                         {'base_withdrawal_fee': '0.000000000000000000'...
# underlying_asset                      {'base_withdrawal_fee': '0.000000000000000000'...
# trading_status                                                              operational
# liquidation_penalty_factor                                                          0.5
# impact_size                                                                         200
# state                                                                              live
# settling_asset                        {'base_withdrawal_fee': '0.000000000000000000'...
# id                                                                                88584
# tick_size                                                                           0.1
# barrier_price                                                                      None
# auction_finish_time                                                                None
# annualized_funding                                                                10.95
# funding_method                                                               mark_price
# is_quanto                                                                         False
# max_leverage_notional                                                            200000
# launch_time                                                        2025-08-07T13:40:09Z
# contract_unit_currency                                                              BTC
# contract_type                                                               put_options
# maintenance_margin                                                                  0.5
# basis_factor_max_limit                                                            10.95
# notional_type                                                                   vanilla
# price_band                                                                            2
# position_size_limit                                                              255633
# settlement_price                                                                   None
# contract_value                                                                    0.001
# maintenance_margin_scaling_factor                                              0.000001
# ui_config                             {'default_trading_view_candle': '15', 'leverag...
# default_leverage                                                 100.000000000000000000
# auction_start_time                                                 2025-08-07T13:40:09Z
# strike_price                                                                     119200
# symbol                                                              P-BTC-119200-100825
# short_description                                                              BTC  Put
# spot_index                            {'config': {'price_alert_enabled': True, 'quot...
# product_specs                         {'backup_vol_expiry_time': 31536000, 'isolated...
# taker_commission_rate                                                           0.00015
# description                                        BTC put option expiring on 10-8-2025
# initial_margin                                                                        1
# initial_margin_scaling_factor                                                  0.000002
# Name: 0, dtype: object

# %%
symdf['settlement_time'] =pd.to_datetime(symdf['settlement_time'], utc=True)
symdf['expiry'] = symdf['settlement_time'].dt.date
symdf
# Out:
#      maker_commission_rate disruption_reason  \
# 0                  0.00015              None
# 1                  0.00015              None
# 2                  0.00015              None
# 3                  0.00015              None
# 4                  0.00015              None
# ...                    ...               ...
# 1068                0.0002              None
# 1069                0.0002              None
# 1070                0.0002              None
# 1071                0.0002              None
# 1072                0.0002              None
#
#      insurance_fund_margin_contribution           settlement_time  \
# 0                                     5 2025-08-10 12:00:00+00:00
# 1                                     5 2025-08-10 12:00:00+00:00
# 2                                     5 2025-08-10 12:00:00+00:00
# 3                                     5 2025-08-09 12:00:00+00:00
# 4                                     5 2025-08-09 12:00:00+00:00
# ...                                 ...                       ...
# 1068                                  5                       NaT
# 1069                                  5                       NaT
# 1070                                  5                       NaT
# 1071                                  5                       NaT
# 1072                                  5                       NaT
#
#                                           quoting_asset  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...
# 1     {'base_withdrawal_fee': '0.000000000000000000'...
# 2     {'base_withdrawal_fee': '0.000000000000000000'...
# 3     {'base_withdrawal_fee': '0.000000000000000000'...
# 4     {'base_withdrawal_fee': '0.000000000000000000'...
# ...                                                 ...
# 1068  {'base_withdrawal_fee': '0.000000000000000000'...
# 1069  {'base_withdrawal_fee': '0.000000000000000000'...
# 1070  {'base_withdrawal_fee': '0.000000000000000000'...
# 1071  {'base_withdrawal_fee': '0.000000000000000000'...
# 1072  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                        underlying_asset trading_status  \
# 0     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 2     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 3     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 4     {'base_withdrawal_fee': '0.000000000000000000'...    operational
# ...                                                 ...            ...
# 1068  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1069  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1070  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1071  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 1072  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#      liquidation_penalty_factor  impact_size state  ... strike_price  \
# 0                           0.5          200  live  ...       119200
# 1                           0.5          300  live  ...         3940
# 2                           0.5          300  live  ...         3940
# 3                           0.5          300  live  ...         3940
# 4                           0.5          300  live  ...         4040
# ...                         ...          ...   ...  ...          ...
# 1068                        0.2         2469  live  ...         None
# 1069                        0.2         1500  live  ...         None
# 1070                        0.2         5282  live  ...         None
# 1071                        0.2         9591  live  ...         None
# 1072                        0.5        10000  live  ...         None
#
#                    symbol    short_description  \
# 0     P-BTC-119200-100825             BTC  Put
# 1       C-ETH-3940-100825            ETH  Call
# 2       P-ETH-3940-100825             ETH  Put
# 3       C-ETH-3940-090825            ETH  Call
# 4       P-ETH-4040-090825             ETH  Put
# ...                   ...                  ...
# 1068              AVAXUSD  Avalanche Perpetual
# 1069               SOLUSD     Solana Perpetual
# 1070              DOGEUSD   Dogecoin Perpetual
# 1071               ETHUSD   Ethereum Perpetual
# 1072               BTCUSD    Bitcoin Perpetual
#
#                                              spot_index  \
# 0     {'config': {'price_alert_enabled': True, 'quot...
# 1     {'config': {'price_alert_enabled': True, 'quot...
# 2     {'config': {'price_alert_enabled': True, 'quot...
# 3     {'config': {'price_alert_enabled': True, 'quot...
# 4     {'config': {'price_alert_enabled': True, 'quot...
# ...                                                 ...
# 1068  {'config': {'price_alert_enabled': True, 'quot...
# 1069  {'config': {'price_alert_enabled': True, 'quot...
# 1070  {'config': {'price_alert_enabled': True, 'quot...
# 1071  {'config': {'price_alert_enabled': True, 'quot...
# 1072  {'config': {'price_alert_enabled': True, 'quot...
#
#                                           product_specs taker_commission_rate  \
# 0     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 1     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 2     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 3     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 4     {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# ...                                                 ...                   ...
# 1068  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1069  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1070  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1071  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
# 1072  {'funding_clamp_value': 0.05, 'isolated_liq_pe...                0.0005
#
#                                             description  initial_margin  \
# 0                  BTC put option expiring on 10-8-2025               1
# 1                 ETH call option expiring on 10-8-2025               1
# 2                  ETH put option expiring on 10-8-2025               1
# 3                  ETH call option expiring on 9-8-2025               1
# 4                   ETH put option expiring on 9-8-2025               1
# ...                                                 ...             ...
# 1068            Avalance perpetual future quoted in USD               1
# 1069              Solana perpetual future quoted in USD               1
# 1070            Dogecoin perpetual future quoted in USD               1
# 1071  Ethereum Perpetual futures, quoted, settled & ...             0.5
# 1072  Bitcoin Perpetual futures, quoted, settled & m...             0.5
#
#      initial_margin_scaling_factor      expiry
# 0                         0.000002  2025-08-10
# 1                         0.000004  2025-08-10
# 2                         0.000004  2025-08-10
# 3                         0.000004  2025-08-09
# 4                         0.000004  2025-08-09
# ...                            ...         ...
# 1068                      0.000004         NaT
# 1069                      0.000004         NaT
# 1070                      0.000004         NaT
# 1071                      0.000004         NaT
# 1072                     0.0000025         NaT
#
# [1073 rows x 43 columns]

# %%
expiryDate= datetime.now() +  timedelta(days=1)
btcdf = symdf[(symdf.expiry ==expiryDate.date() )& (symdf.contract_unit_currency == 'BTC') ]
btcdf
# Out:
#     maker_commission_rate disruption_reason  \
# 80                0.00015              None
# 81                0.00015              None
# 82                0.00015              None
# 83                0.00015              None
# 86                0.00015              None
# ..                    ...               ...
# 776               0.00015              None
# 777               0.00015              None
# 778               0.00015              None
# 779               0.00015              None
# 780               0.00015              None
#
#     insurance_fund_margin_contribution           settlement_time  \
# 80                                   5 2025-08-08 12:00:00+00:00
# 81                                   5 2025-08-08 12:00:00+00:00
# 82                                   5 2025-08-08 12:00:00+00:00
# 83                                   5 2025-08-08 12:00:00+00:00
# 86                                   5 2025-08-08 12:00:00+00:00
# ..                                 ...                       ...
# 776                                  5 2025-08-08 12:00:00+00:00
# 777                                  5 2025-08-08 12:00:00+00:00
# 778                                  5 2025-08-08 12:00:00+00:00
# 779                                  5 2025-08-08 12:00:00+00:00
# 780                                  5 2025-08-08 12:00:00+00:00
#
#                                          quoting_asset  \
# 80   {'base_withdrawal_fee': '0.000000000000000000'...
# 81   {'base_withdrawal_fee': '0.000000000000000000'...
# 82   {'base_withdrawal_fee': '0.000000000000000000'...
# 83   {'base_withdrawal_fee': '0.000000000000000000'...
# 86   {'base_withdrawal_fee': '0.000000000000000000'...
# ..                                                 ...
# 776  {'base_withdrawal_fee': '0.000000000000000000'...
# 777  {'base_withdrawal_fee': '0.000000000000000000'...
# 778  {'base_withdrawal_fee': '0.000000000000000000'...
# 779  {'base_withdrawal_fee': '0.000000000000000000'...
# 780  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                       underlying_asset trading_status  \
# 80   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 81   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 82   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 83   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 86   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# ..                                                 ...            ...
# 776  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 777  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 778  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 779  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 780  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#     liquidation_penalty_factor  impact_size state  ... strike_price  \
# 80                         0.5          200  live  ...       117800
# 81                         0.5          200  live  ...       118200
# 82                         0.5          200  live  ...       117800
# 83                         0.5          200  live  ...       118200
# 86                         0.5          200  live  ...       117600
# ..                         ...          ...   ...  ...          ...
# 776                        0.5          200  live  ...       118500
# 777                        0.5          200  live  ...       119000
# 778                        0.5          200  live  ...       119500
# 779                        0.5          200  live  ...       120000
# 780                        0.5          200  live  ...       120500
#
#                   symbol short_description  \
# 80   C-BTC-117800-080825         BTC  Call
# 81   C-BTC-118200-080825         BTC  Call
# 82   P-BTC-117800-080825          BTC  Put
# 83   P-BTC-118200-080825          BTC  Put
# 86   C-BTC-117600-080825         BTC  Call
# ..                   ...               ...
# 776  P-BTC-118500-080825          BTC  Put
# 777  P-BTC-119000-080825          BTC  Put
# 778  P-BTC-119500-080825          BTC  Put
# 779  P-BTC-120000-080825          BTC  Put
# 780  P-BTC-120500-080825          BTC  Put
#
#                                             spot_index  \
# 80   {'config': {'price_alert_enabled': True, 'quot...
# 81   {'config': {'price_alert_enabled': True, 'quot...
# 82   {'config': {'price_alert_enabled': True, 'quot...
# 83   {'config': {'price_alert_enabled': True, 'quot...
# 86   {'config': {'price_alert_enabled': True, 'quot...
# ..                                                 ...
# 776  {'config': {'price_alert_enabled': True, 'quot...
# 777  {'config': {'price_alert_enabled': True, 'quot...
# 778  {'config': {'price_alert_enabled': True, 'quot...
# 779  {'config': {'price_alert_enabled': True, 'quot...
# 780  {'config': {'price_alert_enabled': True, 'quot...
#
#                                          product_specs taker_commission_rate  \
# 80   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 81   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 82   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 83   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 86   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# ..                                                 ...                   ...
# 776  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 777  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 778  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 779  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 780  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                               description  initial_margin  \
# 80   BTC call option expiring on 8-8-2025             0.5
# 81   BTC call option expiring on 8-8-2025             0.5
# 82    BTC put option expiring on 8-8-2025             0.5
# 83    BTC put option expiring on 8-8-2025             0.5
# 86   BTC call option expiring on 8-8-2025             0.5
# ..                                    ...             ...
# 776   BTC put option expiring on 8-8-2025             0.5
# 777   BTC put option expiring on 8-8-2025             0.5
# 778   BTC put option expiring on 8-8-2025             0.5
# 779   BTC put option expiring on 8-8-2025             0.5
# 780   BTC put option expiring on 8-8-2025             0.5
#
#     initial_margin_scaling_factor      expiry
# 80                       0.000002  2025-08-08
# 81                       0.000002  2025-08-08
# 82                       0.000002  2025-08-08
# 83                       0.000002  2025-08-08
# 86                       0.000002  2025-08-08
# ..                            ...         ...
# 776                      0.000002  2025-08-08
# 777                      0.000002  2025-08-08
# 778                      0.000002  2025-08-08
# 779                      0.000002  2025-08-08
# 780                      0.000002  2025-08-08
#
# [123 rows x 43 columns]

# %%
btcdf.contract_type.unique()
# Out:
# array(['call_options', 'put_options'], dtype=object)

# %%
btcdf[btcdf.contract_type == 'call_options']
# Out:
#     maker_commission_rate disruption_reason  \
# 80                0.00015              None
# 81                0.00015              None
# 86                0.00015              None
# 92                0.00015              None
# 94                0.00015              None
# ..                    ...               ...
# 771               0.00015              None
# 772               0.00015              None
# 773               0.00015              None
# 774               0.00015              None
# 775               0.00015              None
#
#     insurance_fund_margin_contribution           settlement_time  \
# 80                                   5 2025-08-08 12:00:00+00:00
# 81                                   5 2025-08-08 12:00:00+00:00
# 86                                   5 2025-08-08 12:00:00+00:00
# 92                                   5 2025-08-08 12:00:00+00:00
# 94                                   5 2025-08-08 12:00:00+00:00
# ..                                 ...                       ...
# 771                                  5 2025-08-08 12:00:00+00:00
# 772                                  5 2025-08-08 12:00:00+00:00
# 773                                  5 2025-08-08 12:00:00+00:00
# 774                                  5 2025-08-08 12:00:00+00:00
# 775                                  5 2025-08-08 12:00:00+00:00
#
#                                          quoting_asset  \
# 80   {'base_withdrawal_fee': '0.000000000000000000'...
# 81   {'base_withdrawal_fee': '0.000000000000000000'...
# 86   {'base_withdrawal_fee': '0.000000000000000000'...
# 92   {'base_withdrawal_fee': '0.000000000000000000'...
# 94   {'base_withdrawal_fee': '0.000000000000000000'...
# ..                                                 ...
# 771  {'base_withdrawal_fee': '0.000000000000000000'...
# 772  {'base_withdrawal_fee': '0.000000000000000000'...
# 773  {'base_withdrawal_fee': '0.000000000000000000'...
# 774  {'base_withdrawal_fee': '0.000000000000000000'...
# 775  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                       underlying_asset trading_status  \
# 80   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 81   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 86   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 92   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 94   {'base_withdrawal_fee': '0.000000000000000000'...    operational
# ..                                                 ...            ...
# 771  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 772  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 773  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 774  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 775  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#     liquidation_penalty_factor  impact_size state  ... strike_price  \
# 80                         0.5          200  live  ...       117800
# 81                         0.5          200  live  ...       118200
# 86                         0.5          200  live  ...       117600
# 92                         0.5          200  live  ...       117400
# 94                         0.5          200  live  ...       117200
# ..                         ...          ...   ...  ...          ...
# 771                        0.5          200  live  ...       118500
# 772                        0.5          200  live  ...       119000
# 773                        0.5          200  live  ...       119500
# 774                        0.5          200  live  ...       120000
# 775                        0.5          200  live  ...       120500
#
#                   symbol short_description  \
# 80   C-BTC-117800-080825         BTC  Call
# 81   C-BTC-118200-080825         BTC  Call
# 86   C-BTC-117600-080825         BTC  Call
# 92   C-BTC-117400-080825         BTC  Call
# 94   C-BTC-117200-080825         BTC  Call
# ..                   ...               ...
# 771  C-BTC-118500-080825         BTC  Call
# 772  C-BTC-119000-080825         BTC  Call
# 773  C-BTC-119500-080825         BTC  Call
# 774  C-BTC-120000-080825         BTC  Call
# 775  C-BTC-120500-080825         BTC  Call
#
#                                             spot_index  \
# 80   {'config': {'price_alert_enabled': True, 'quot...
# 81   {'config': {'price_alert_enabled': True, 'quot...
# 86   {'config': {'price_alert_enabled': True, 'quot...
# 92   {'config': {'price_alert_enabled': True, 'quot...
# 94   {'config': {'price_alert_enabled': True, 'quot...
# ..                                                 ...
# 771  {'config': {'price_alert_enabled': True, 'quot...
# 772  {'config': {'price_alert_enabled': True, 'quot...
# 773  {'config': {'price_alert_enabled': True, 'quot...
# 774  {'config': {'price_alert_enabled': True, 'quot...
# 775  {'config': {'price_alert_enabled': True, 'quot...
#
#                                          product_specs taker_commission_rate  \
# 80   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 81   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 86   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 92   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 94   {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# ..                                                 ...                   ...
# 771  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 772  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 773  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 774  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 775  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                               description  initial_margin  \
# 80   BTC call option expiring on 8-8-2025             0.5
# 81   BTC call option expiring on 8-8-2025             0.5
# 86   BTC call option expiring on 8-8-2025             0.5
# 92   BTC call option expiring on 8-8-2025             0.5
# 94   BTC call option expiring on 8-8-2025             0.5
# ..                                    ...             ...
# 771  BTC call option expiring on 8-8-2025             0.5
# 772  BTC call option expiring on 8-8-2025             0.5
# 773  BTC call option expiring on 8-8-2025             0.5
# 774  BTC call option expiring on 8-8-2025             0.5
# 775  BTC call option expiring on 8-8-2025             0.5
#
#     initial_margin_scaling_factor      expiry
# 80                       0.000002  2025-08-08
# 81                       0.000002  2025-08-08
# 86                       0.000002  2025-08-08
# 92                       0.000002  2025-08-08
# 94                       0.000002  2025-08-08
# ..                            ...         ...
# 771                      0.000002  2025-08-08
# 772                      0.000002  2025-08-08
# 773                      0.000002  2025-08-08
# 774                      0.000002  2025-08-08
# 775                      0.000002  2025-08-08
#
# [63 rows x 43 columns]

# %%
btcdf_calloption=btcdf[btcdf.contract_type == 'call_options']

# %%
btcdf_calloption.head()
# Out:
#    maker_commission_rate disruption_reason insurance_fund_margin_contribution  \
# 80               0.00015              None                                  5
# 81               0.00015              None                                  5
# 86               0.00015              None                                  5
# 92               0.00015              None                                  5
# 94               0.00015              None                                  5
#
#              settlement_time  \
# 80 2025-08-08 12:00:00+00:00
# 81 2025-08-08 12:00:00+00:00
# 86 2025-08-08 12:00:00+00:00
# 92 2025-08-08 12:00:00+00:00
# 94 2025-08-08 12:00:00+00:00
#
#                                         quoting_asset  \
# 80  {'base_withdrawal_fee': '0.000000000000000000'...
# 81  {'base_withdrawal_fee': '0.000000000000000000'...
# 86  {'base_withdrawal_fee': '0.000000000000000000'...
# 92  {'base_withdrawal_fee': '0.000000000000000000'...
# 94  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                      underlying_asset trading_status  \
# 80  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 81  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 86  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 92  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 94  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#    liquidation_penalty_factor  impact_size state  ... strike_price  \
# 80                        0.5          200  live  ...       117800
# 81                        0.5          200  live  ...       118200
# 86                        0.5          200  live  ...       117600
# 92                        0.5          200  live  ...       117400
# 94                        0.5          200  live  ...       117200
#
#                  symbol short_description  \
# 80  C-BTC-117800-080825         BTC  Call
# 81  C-BTC-118200-080825         BTC  Call
# 86  C-BTC-117600-080825         BTC  Call
# 92  C-BTC-117400-080825         BTC  Call
# 94  C-BTC-117200-080825         BTC  Call
#
#                                            spot_index  \
# 80  {'config': {'price_alert_enabled': True, 'quot...
# 81  {'config': {'price_alert_enabled': True, 'quot...
# 86  {'config': {'price_alert_enabled': True, 'quot...
# 92  {'config': {'price_alert_enabled': True, 'quot...
# 94  {'config': {'price_alert_enabled': True, 'quot...
#
#                                         product_specs taker_commission_rate  \
# 80  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 81  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 86  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 92  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 94  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                              description  initial_margin  \
# 80  BTC call option expiring on 8-8-2025             0.5
# 81  BTC call option expiring on 8-8-2025             0.5
# 86  BTC call option expiring on 8-8-2025             0.5
# 92  BTC call option expiring on 8-8-2025             0.5
# 94  BTC call option expiring on 8-8-2025             0.5
#
#    initial_margin_scaling_factor      expiry
# 80                      0.000002  2025-08-08
# 81                      0.000002  2025-08-08
# 86                      0.000002  2025-08-08
# 92                      0.000002  2025-08-08
# 94                      0.000002  2025-08-08
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Get product by ID

# %%
delta_client.get_product('63146')
# Out:
# {'initial_margin_scaling_factor': '0.000004',
#  'maintenance_margin_scaling_factor': '0.000002',
#  'settlement_price': '0',
#  'auction_finish_time': None,
#  'maker_commission_rate': '0.0003',
#  'basis_factor_max_limit': '10.95',
#  'state': 'expired',
#  'quoting_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'disruption_reason': None,
#  'short_description': 'ETH  Call',
#  'id': 63146,
#  'strike_price': '2860',
#  'default_leverage': '100.000000000000000000',
#  'position_size_limit': 173467,
#  'price_band': '2',
#  'liquidation_penalty_factor': '0.5',
#  'tick_size': '0.01',
#  'impact_size': 300,
#  'taker_commission_rate': '0.0003',
#  'contract_type': 'call_options',
#  'barrier_price': None,
#  'spot_index': {'config': {'price_alert_enabled': True,
#    'quoting_asset': 'USD',
#    'service_id': 1,
#    'underlying_asset': 'ETH'},
#   'constituent_exchanges': [],
#   'constituent_indices': {'expression': '${e1} * ${e2}',
#    'indices': {'e1': '.DEETHUSDT', 'e2': '.DEUSDTUSD'}},
#   'description': 'ETH spot price index quoted in US Dollar',
#   'health_interval': 300,
#   'id': 17,
#   'impact_size': '4.000000000000000000',
#   'index_type': 'spot_pair',
#   'is_composite': True,
#   'price_method': 'orderbook',
#   'quoting_asset_id': 14,
#   'symbol': '.DEETHUSD',
#   'tick_size': '0.010000000000000000',
#   'underlying_asset_id': 12},
#  'product_specs': {'backup_vol_expiry_time': 31536000,
#   'max_deviation_from_external_vol': 0.75,
#   'max_lower_deviation_from_external_vol': 0.75,
#   'max_upper_deviation_from_external_vol': 0.5,
#   'max_volatility': 3,
#   'min_volatility': 0.1,
#   'only_reduce_only_orders_allowed': False,
#   'premium_commission_rate': 0.1,
#   'settlement_index_price': '2408.1751724137926',
#   'vol_calculation_method': 'orderbook',
#   'vol_expiry_time': 31536000},
#  'launch_time': '2025-02-22T16:05:09Z',
#  'symbol': 'C-ETH-2860-250225',
#  'settlement_time': '2025-02-25T12:00:00Z',
#  'trading_status': 'operational',
#  'notional_type': 'vanilla',
#  'settling_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'underlying_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 12,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 4,
#   'name': 'Ethereum',
#   'networks': [],
#   'precision': 18,
#   'sort_priority': 2,
#   'symbol': 'ETH',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'initial_margin': '1',
#  'insurance_fund_margin_contribution': '1',
#  'maintenance_margin': '0.5',
#  'is_quanto': False,
#  'contract_value': '0.01',
#  'max_leverage_notional': '100000',
#  'ui_config': {'default_trading_view_candle': '15',
#   'leverage_slider_values': [1, 2, 5, 10, 20, 50, 100],
#   'price_clubbing_values': [0.01, 0.05, 0.1, 0.5, 1, 2.5, 5],
#   'show_bracket_orders': False,
#   'sort_priority': 1,
#   'tags': []},
#  'funding_method': 'mark_price',
#  'annualized_funding': '10.95',
#  'description': 'ETH call option expiring on 25-2-2025',
#  'auction_start_time': '2025-02-22T16:05:09Z',
#  'contract_unit_currency': 'ETH'}

# %%
delta_client.get_product('C-ETH-3740-050825')
# Out:
# {'impact_size': 300,
#  'default_leverage': '100.000000000000000000',
#  'auction_start_time': '2025-08-04T14:25:14Z',
#  'settlement_time': '2025-08-05T12:00:00Z',
#  'state': 'expired',
#  'contract_value': '0.01',
#  'annualized_funding': '10.95',
#  'trading_status': 'operational',
#  'initial_margin': '1',
#  'id': 88229,
#  'insurance_fund_margin_contribution': '5',
#  'taker_commission_rate': '0.00015',
#  'quoting_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'tick_size': '0.01',
#  'maintenance_margin_scaling_factor': '0.000002',
#  'symbol': 'C-ETH-3740-050825',
#  'price_band': '2',
#  'product_specs': {'backup_vol_expiry_time': 31536000,
#   'isolated_liq_penalty_factor': 0.001,
#   'isolated_liq_premium_penalty_factor': 0.2,
#   'max_deviation_from_external_vol': 0.75,
#   'max_lower_deviation_from_external_vol': 0.75,
#   'max_upper_deviation_from_external_vol': 0.5,
#   'max_volatility': 3,
#   'min_volatility': 0.1,
#   'only_reduce_only_orders_allowed': False,
#   'premium_commission_rate': 0.1,
#   'settlement_index_price': '3672.564827586208',
#   'vol_calculation_method': 'orderbook',
#   'vol_expiry_time': 31536000},
#  'launch_time': '2025-08-04T14:25:14Z',
#  'initial_margin_scaling_factor': '0.000004',
#  'maker_commission_rate': '0.00015',
#  'underlying_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 12,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 4,
#   'name': 'Ethereum',
#   'networks': [],
#   'precision': 18,
#   'sort_priority': 2,
#   'symbol': 'ETH',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'contract_unit_currency': 'ETH',
#  'ui_config': {'default_trading_view_candle': '15',
#   'leverage_slider_values': [1, 2, 5, 10, 20, 50, 100],
#   'price_clubbing_values': [0.01, 0.05, 0.1, 0.5, 1, 2.5, 5],
#   'show_bracket_orders': False,
#   'sort_priority': 1,
#   'tags': []},
#  'funding_method': 'mark_price',
#  'auction_finish_time': None,
#  'is_quanto': False,
#  'basis_factor_max_limit': '10.95',
#  'position_size_limit': 173467,
#  'barrier_price': None,
#  'maintenance_margin': '0.5',
#  'liquidation_penalty_factor': '0.5',
#  'strike_price': '3740',
#  'disruption_reason': None,
#  'contract_type': 'call_options',
#  'settling_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'spot_index': {'config': {'price_alert_enabled': True,
#    'quoting_asset': 'USD',
#    'service_id': 1,
#    'underlying_asset': 'ETH'},
#   'constituent_exchanges': [],
#   'constituent_indices': {'expression': '${e1} * ${e2}',
#    'indices': {'e1': '.DEETHUSDT', 'e2': '.DEUSDTUSD'}},
#   'description': 'ETH spot price index quoted in US Dollar',
#   'health_interval': 300,
#   'id': 17,
#   'impact_size': '4.000000000000000000',
#   'index_type': 'spot_pair',
#   'is_composite': True,
#   'price_method': 'orderbook',
#   'quoting_asset_id': 14,
#   'symbol': '.DEETHUSD',
#   'tick_size': '0.010000000000000000',
#   'underlying_asset_id': 12},
#  'settlement_price': '0',
#  'notional_type': 'vanilla',
#  'short_description': 'ETH  Call',
#  'max_leverage_notional': '100000',
#  'description': 'ETH call option expiring on 5-8-2025'}

# %%
ethdf = symdf[(symdf.expiry ==expiryDate.date() )& (symdf.contract_unit_currency == 'ETH') ]

# %%
ethdf.head()
# Out:
#     maker_commission_rate disruption_reason  \
# 160               0.00015              None
# 161               0.00015              None
# 162               0.00015              None
# 165               0.00015              None
# 166               0.00015              None
#
#     insurance_fund_margin_contribution           settlement_time  \
# 160                                  5 2025-08-07 12:00:00+00:00
# 161                                  5 2025-08-07 12:00:00+00:00
# 162                                  5 2025-08-07 12:00:00+00:00
# 165                                  5 2025-08-07 12:00:00+00:00
# 166                                  5 2025-08-07 12:00:00+00:00
#
#                                          quoting_asset  \
# 160  {'base_withdrawal_fee': '0.000000000000000000'...
# 161  {'base_withdrawal_fee': '0.000000000000000000'...
# 162  {'base_withdrawal_fee': '0.000000000000000000'...
# 165  {'base_withdrawal_fee': '0.000000000000000000'...
# 166  {'base_withdrawal_fee': '0.000000000000000000'...
#
#                                       underlying_asset trading_status  \
# 160  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 161  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 162  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 165  {'base_withdrawal_fee': '0.000000000000000000'...    operational
# 166  {'base_withdrawal_fee': '0.000000000000000000'...    operational
#
#     liquidation_penalty_factor  impact_size state  ... strike_price  \
# 160                        0.5          300  live  ...         3820
# 161                        0.5          300  live  ...         3820
# 162                        0.5          300  live  ...         3920
# 165                        0.5          300  live  ...         3920
# 166                        0.5          300  live  ...         3780
#
#                 symbol short_description  \
# 160  C-ETH-3820-070825         ETH  Call
# 161  P-ETH-3820-070825          ETH  Put
# 162  P-ETH-3920-070825          ETH  Put
# 165  C-ETH-3920-070825         ETH  Call
# 166  C-ETH-3780-070825         ETH  Call
#
#                                             spot_index  \
# 160  {'config': {'price_alert_enabled': True, 'quot...
# 161  {'config': {'price_alert_enabled': True, 'quot...
# 162  {'config': {'price_alert_enabled': True, 'quot...
# 165  {'config': {'price_alert_enabled': True, 'quot...
# 166  {'config': {'price_alert_enabled': True, 'quot...
#
#                                          product_specs taker_commission_rate  \
# 160  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 161  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 162  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 165  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
# 166  {'backup_vol_expiry_time': 31536000, 'isolated...               0.00015
#
#                               description  initial_margin  \
# 160  ETH call option expiring on 7-8-2025               1
# 161   ETH put option expiring on 7-8-2025               1
# 162   ETH put option expiring on 7-8-2025               1
# 165  ETH call option expiring on 7-8-2025               1
# 166  ETH call option expiring on 7-8-2025               1
#
#     initial_margin_scaling_factor      expiry
# 160                      0.000004  2025-08-07
# 161                      0.000004  2025-08-07
# 162                      0.000004  2025-08-07
# 165                      0.000004  2025-08-07
# 166                      0.000004  2025-08-07
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Get Ticker

# %%
# Get Ticker
delta_client.get_ticker('BTCUSD')
# Out:
# {'price_band': {'lower_limit': '110397.09293146',
#   'upper_limit': '122017.83955582'},
#  'spot_price': '116236.4',
#  'greeks': None,
#  'tags': ['layer_1'],
#  'mark_price': '116194.14126847',
#  'symbol': 'BTCUSD',
#  'mark_change_24h': '1.7868',
#  'tick_size': '0.500000000000000000',
#  'underlying_asset_symbol': 'BTC',
#  'volume': 4643.088000000205,
#  'oi_value': '394.8790',
#  'close': 116194.5,
#  'sort_priority': 1,
#  'oi_value_symbol': 'BTC',
#  'product_id': 27,
#  'turnover': 535616350.9660083,
#  'initial_margin': '0.500000000000000000',
#  'oi': '394.8790',
#  'contract_value': '0.001000000000000000',
#  'oi_value_usd': '45899313.3956',
#  'low': 113818.0,
#  'open': 114341.5,
#  'quotes': {'ask_iv': None,
#   'ask_size': '970',
#   'best_ask': '116205',
#   'best_ask_mm': None,
#   'best_bid': '116204',
#   'best_bid_mm': None,
#   'bid_iv': None,
#   'bid_size': '2802',
#   'impact_mid_price': None,
#   'mark_iv': '-0.40629006'},
#  'high': 116795.0,
#  'funding_rate': '0.01',
#  'oi_contracts': '394879',
#  'turnover_usd': 535616350.9660083,
#  'timestamp': 1754576001125230,
#  'time': '2025-08-06T14:09:11.301361274Z',
#  'size': 4643088,
#  'turnover_symbol': 'USD',
#  'mark_basis': '-0.4084552',
#  'contract_type': 'perpetual_futures',
#  'description': 'Bitcoin Perpetual',
#  'oi_change_usd_6h': '-8314183.7200'}

# %%
delta_client.get_ticker('C-BTC-113400-080825')
# Out:
# {'price_band': {'lower_limit': '645.73532514', 'upper_limit': '5297.64579596'},
#  'spot_price': '116290',
#  'greeks': {'delta': '0.91632352',
#   'gamma': '0.00007201',
#   'rho': '2.57156962',
#   'spot': '116292.7',
#   'theta': '-181.23570393',
#   'vega': '8.91084608'},
#  'tags': [],
#  'mark_price': '2971.84606925',
#  'symbol': 'C-BTC-113400-080825',
#  'mark_change_24h': '103.7456',
#  'tick_size': '0.100000000000000000',
#  'underlying_asset_symbol': 'BTC',
#  'volume': 1.6720000000000002,
#  'oi_value': '0.0010',
#  'close': 3026.0,
#  'sort_priority': 1,
#  'oi_value_symbol': 'BTC',
#  'product_id': 88300,
#  'turnover': 191465.2688,
#  'strike_price': '113400',
#  'initial_margin': '0.500000000000000000',
#  'oi': '0.0010',
#  'contract_value': '0.001000000000000000',
#  'oi_value_usd': '116.2663',
#  'low': 1200.0,
#  'open': 2183.0,
#  'quotes': {'ask_iv': '0.390913',
#   'ask_size': '2102',
#   'best_ask': '2996',
#   'best_ask_mm': None,
#   'best_bid': '2954',
#   'best_bid_mm': None,
#   'bid_iv': '0.34335646',
#   'bid_size': '3153',
#   'impact_mid_price': None,
#   'mark_iv': '0.36723447'},
#  'high': 3026.0,
#  'oi_contracts': '1',
#  'turnover_usd': 191465.2688,
#  'timestamp': 1754576116448653,
#  'time': '2025-08-06T14:14:12.706411871Z',
#  'mark_vol': '0.36752492',
#  'size': 1672,
#  'turnover_symbol': 'USD',
#  'contract_type': 'call_options',
#  'description': 'BTC  Call',
#  'oi_change_usd_6h': '-348.6800'}

# %%
tickRes = delta_client.get_ticker('')
tickDf = pd.DataFrame(tickRes)
tickDf
# Out:
#      mark_change_24h      mark_price      tags  sort_priority      volume  \
# 0             3.2451      1.83810074    [meme]            130     86060.0
# 1             5.4970      0.05407949    [meme]            130   1207730.0
# 2             3.3147       3.0563983        []              8  22239513.0
# 3             5.7108      0.41303228    [meme]            130    478112.0
# 4             5.2787      0.05026796  [gaming]            130    617520.0
# ...              ...             ...       ...            ...         ...
# 1068         14.5825   1729.43500102        []              1         NaN
# 1069         10.2124  19010.42792365        []              1         NaN
# 1070          9.5996  22382.99119312        []              1         NaN
# 1071        -15.8026   1128.69186488        []              1         NaN
# 1072         33.1707     841.0612079        []              1         NaN
#
#                                                  quotes  \
# 0     {'ask_iv': None, 'ask_size': '5357', 'best_ask...
# 1     {'ask_iv': None, 'ask_size': '9134', 'best_ask...
# 2     {'ask_iv': None, 'ask_size': '7785', 'best_ask...
# 3     {'ask_iv': None, 'ask_size': '1827', 'best_ask...
# 4     {'ask_iv': None, 'ask_size': '1096', 'best_ask...
# ...                                                 ...
# 1068  {'ask_iv': None, 'ask_size': None, 'best_ask':...
# 1069  {'ask_iv': None, 'ask_size': None, 'best_ask':...
# 1070  {'ask_iv': None, 'ask_size': None, 'best_ask':...
# 1071  {'ask_iv': '0.57549063', 'ask_size': '1041', '...
# 1072  {'ask_iv': None, 'ask_size': None, 'best_ask':...
#
#      underlying_asset_symbol funding_rate oi_change_usd_6h  \
# 0                        ZRO  -0.11470285       -1681.7500
# 1                         ZK  -0.07880945        1585.9600
# 2                        XRP         0.01    -1310747.5300
# 3                        XLM  -0.00417219       -9014.6500
# 4                        XAI   0.00995767        -453.4900
# ...                      ...          ...              ...
# 1068                     ETH          NaN           0.0000
# 1069                     BTC          NaN           0.0000
# 1070                     BTC          NaN           0.0000
# 1071                     ETH          NaN           0.0000
# 1072                     ETH          NaN           0.0000
#
#                                              price_band  ...  \
# 0     {'lower_limit': '1.65490427', 'upper_limit': '...  ...
# 1     {'lower_limit': '0.04868654', 'upper_limit': '...  ...
# 2     {'lower_limit': '2.75087843', 'upper_limit': '...  ...
# 3     {'lower_limit': '0.37177185', 'upper_limit': '...  ...
# 4     {'lower_limit': '0.04524064', 'upper_limit': '...  ...
# ...                                                 ...  ...
# 1068  {'lower_limit': '1656.35667254', 'upper_limit'...  ...
# 1069  {'lower_limit': '17042.16317894', 'upper_limit...  ...
# 1070  {'lower_limit': '20145.66904004', 'upper_limit...  ...
# 1071  {'lower_limit': '1062.96218629', 'upper_limit'...  ...
# 1072  {'lower_limit': '771.10692331', 'upper_limit':...  ...
#
#             initial_margin                            time oi_contracts  \
# 0     5.000000000000000000  2025-08-06T14:14:12.706411871Z        10288
# 1     5.000000000000000000  2025-08-06T14:14:12.706411871Z        27265
# 2     1.000000000000000000  2025-08-06T14:14:12.706411871Z      2018915
# 3     5.000000000000000000  2025-08-06T14:14:12.706411871Z       428556
# 4     5.000000000000000000  2025-08-06T14:14:12.706411871Z        59755
# ...                    ...                             ...          ...
# 1068  1.000000000000000000                             NaN            0
# 1069  5.000000000000000000                             NaN            0
# 1070  1.000000000000000000                             NaN            0
# 1071  5.000000000000000000                             NaN           28
# 1072  1.000000000000000000                             NaN            0
#
#             size      turnover turnover_symbol         contract_value  \
# 0        86060.0  1.555322e+05             USD   1.000000000000000000
# 1       120773.0  6.430338e+04             USD  10.000000000000000000
# 2     22239513.0  6.692930e+07             USD   1.000000000000000000
# 3       478112.0  1.931843e+05             USD   1.000000000000000000
# 4        61752.0  3.035571e+04             USD  10.000000000000000000
# ...          ...           ...             ...                    ...
# 1068         NaN           NaN             USD   0.010000000000000000
# 1069         NaN           NaN             USD   0.001000000000000000
# 1070         NaN           NaN             USD   0.001000000000000000
# 1071         NaN           NaN             USD   0.010000000000000000
# 1072         NaN           NaN             USD   0.010000000000000000
#
#               description  strike_price    mark_vol
# 0     LayerZero Perpetual           NaN         NaN
# 1        ZKsync Perpetual           NaN         NaN
# 2        Ripple Perpetual           NaN         NaN
# 3       Stellar Perpetual           NaN         NaN
# 4           XAI Perpetual           NaN         NaN
# ...                   ...           ...         ...
# 1068            ETH  Call          2100  0.92607557
# 1069            BTC  Call         99000    0.465559
# 1070            BTC  Call         94000  0.44204143
# 1071             ETH  Put          4900  0.57970531
# 1072            ETH  Call          3000  0.75908156
#
# [1073 rows x 37 columns]

# %%
tickDf.columns
# Out:
# Index(['mark_change_24h', 'mark_price', 'tags', 'sort_priority', 'volume',
#        'quotes', 'underlying_asset_symbol', 'funding_rate', 'oi_change_usd_6h',
#        'price_band', 'close', 'product_id', 'spot_price', 'tick_size', 'oi',
#        'contract_type', 'symbol', 'low', 'open', 'high', 'greeks', 'oi_value',
#        'mark_basis', 'oi_value_symbol', 'oi_value_usd', 'turnover_usd',
#        'timestamp', 'initial_margin', 'time', 'oi_contracts', 'size',
#        'turnover', 'turnover_symbol', 'contract_value', 'description',
#        'strike_price', 'mark_vol'],
#       dtype='object')

# %%
tickDf[['symbol','time']]
# Out:
#                   symbol                            time
# 0                 ZROUSD  2025-08-06T14:14:12.706411871Z
# 1                  ZKUSD  2025-08-06T14:14:12.706411871Z
# 2                 XRPUSD  2025-08-06T14:14:12.706411871Z
# 3                 XLMUSD  2025-08-06T14:14:12.706411871Z
# 4                 XAIUSD  2025-08-06T14:14:12.706411871Z
# ...                  ...                             ...
# 1068   C-ETH-2100-290825                             NaN
# 1069  C-BTC-99000-260925                             NaN
# 1070  C-BTC-94000-290825                             NaN
# 1071   P-ETH-4900-260925                             NaN
# 1072   C-ETH-3000-220825                             NaN
#
# [1073 rows x 2 columns]

# %%
tickDf.contract_type
# Out:
# 0       perpetual_futures
# 1       perpetual_futures
# 2       perpetual_futures
# 3       perpetual_futures
# 4       perpetual_futures
#               ...
# 1068         call_options
# 1069         call_options
# 1070         call_options
# 1071          put_options
# 1072         call_options
# Name: contract_type, Length: 1073, dtype: object

# %%
tickRes = delta_client.get_ticker('?contract_types=put_options')
tickDf = pd.DataFrame(tickRes)
tickDf
# Out:
#     tags spot_price                                             quotes  \
# 0     []    3839.36  {'ask_iv': '0.6267757', 'ask_size': '543', 'be...
# 1     []    3839.36  {'ask_iv': '0.57823339', 'ask_size': '1035', '...
# 2     []    3839.36  {'ask_iv': '0.5977997', 'ask_size': '543', 'be...
# 3     []    3839.36  {'ask_iv': '0.63990965', 'ask_size': '1079', '...
# 4     []    3839.36  {'ask_iv': '0.59380081', 'ask_size': '558', 'b...
# ..   ...        ...                                                ...
# 444   []   116474.7  {'ask_iv': '0.23883519', 'ask_size': '1552', '...
# 445   []    3839.36  {'ask_iv': '0.57979286', 'ask_size': '1034', '...
# 446   []   116474.7  {'ask_iv': '0.25294462', 'ask_size': '870', 'b...
# 447   []    3839.36  {'ask_iv': '0.5169899', 'ask_size': '1235', 'b...
# 448   []    3839.36  {'ask_iv': '0.57558991', 'ask_size': '1037', '...
#
#                 tick_size  close    mark_vol  product_id  volume  \
# 0    0.010000000000000000  886.2  0.64351395       85432    0.02
# 1    0.010000000000000000  854.8  0.54646363       86693    0.01
# 2    0.010000000000000000  523.8  0.56647756       85230    0.01
# 3    0.010000000000000000  459.7  0.56659252       86632    3.01
# 4    0.010000000000000000  455.0  0.56938391       85153    0.05
# ..                    ...    ...         ...         ...     ...
# 444  0.100000000000000000    NaN  0.23635744       88508     NaN
# 445  0.010000000000000000    NaN  0.56200098       86675     NaN
# 446  0.100000000000000000    NaN   0.2424497       86725     NaN
# 447  0.010000000000000000    NaN  0.49702027       88582     NaN
# 448  0.010000000000000000    NaN  0.58017384       87050     NaN
#
#      turnover_usd oi_contracts  ...      oi  strike_price  \
# 0         74.9324            1  ...  0.0100          4700
# 1         38.0933           10  ...  0.1000          4600
# 2         38.2850            1  ...  0.0100          4300
# 3      11577.4918          501  ...  5.0100          4300
# 4        190.8695          155  ...  1.5500          4200
# ..            ...          ...  ...     ...           ...
# 444           NaN            0  ...  0.0000        117000
# 445           NaN            0  ...  0.0000          4300
# 446           NaN            1  ...  0.0010        128000
# 447           NaN            0  ...  0.0000          3940
# 448           NaN           28  ...  0.2800          4900
#
#                   symbol                                             greeks  \
# 0      P-ETH-4700-290825  {'delta': '-0.88575481', 'gamma': '0.00031922'...
# 1      P-ETH-4600-260925  {'delta': '-0.78615282', 'gamma': '0.00037534'...
# 2      P-ETH-4300-290825  {'delta': '-0.77242755', 'gamma': '0.00056638'...
# 3      P-ETH-4300-150825  {'delta': '-0.90615462', 'gamma': '0.00052347'...
# 4      P-ETH-4200-290825  {'delta': '-0.71674530', 'gamma': '0.00063147'...
# ..                   ...                                                ...
# 444  P-BTC-117000-100825  {'delta': '-0.58022824', 'gamma': '0.00015918'...
# 445    P-ETH-4300-260925  {'delta': '-0.67046047', 'gamma': '0.00045353'...
# 446  P-BTC-128000-260925  {'delta': '-0.84303290', 'gamma': '0.00002300'...
# 447    P-ETH-3940-100825  {'delta': '-0.71254212', 'gamma': '0.00200151'...
# 448    P-ETH-4900-260925  {'delta': '-0.81830197', 'gamma': '0.00028962'...
#
#     underlying_asset_symbol oi_change_usd_6h    turnover  mark_change_24h  \
# 0                       ETH           0.0000     74.9324         -19.1174
# 1                       ETH           0.0000     38.0933         -19.0398
# 2                       ETH          38.3700     38.2850         -27.6414
# 3                       ETH       11510.1900  11577.4918         -31.6487
# 4                       ETH         191.8400    190.8695         -29.0880
# ..                      ...              ...         ...              ...
# 444                     BTC           0.0000         NaN          92.9537
# 445                     ETH           0.0000         NaN         -20.7708
# 446                     BTC           0.0000         NaN         -12.0897
# 447                     ETH           0.0000         NaN          46.0810
# 448                     ETH           0.0000         NaN         -16.1852
#
#      description        initial_margin
# 0       ETH  Put  1.000000000000000000
# 1       ETH  Put  5.000000000000000000
# 2       ETH  Put  1.000000000000000000
# 3       ETH  Put  1.000000000000000000
# 4       ETH  Put  1.000000000000000000
# ..           ...                   ...
# 444     BTC  Put  1.000000000000000000
# 445     ETH  Put  5.000000000000000000
# 446     BTC  Put  5.000000000000000000
# 447     ETH  Put  1.000000000000000000
# 448     ETH  Put  5.000000000000000000
#
# [449 rows x 35 columns]

# %%
import requests
headers = {
  'Accept': 'application/json'
}

r = requests.get('https://api.india.delta.exchange/v2/assets', params={

}, headers = headers)

print(r.json())
# Out:
# {'result': [{'base_withdrawal_fee': '0.000000000000000000', 'id': 12, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 4, 'name': 'Ethereum', 'networks': [], 'precision': 18, 'sort_priority': 2, 'symbol': 'ETH', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 13, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 4, 'name': 'Bitcoin', 'networks': [], 'precision': 8, 'sort_priority': 1, 'symbol': 'BTC', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 14, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 2, 'name': 'US Dollar', 'networks': [{'allowed_deposit_groups': None, 'base_withdrawal_fee': '0', 'deposit_status': 'enabled', 'memo_required': False, 'min_deposit_amount': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_deposit_confirmations': 1, 'network': 'INR_BANKING', 'variable_withdrawal_fee': '0', 'withdrawal_status': 'enabled'}], 'precision': 8, 'sort_priority': 3, 'symbol': 'USD', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 15, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 2, 'name': 'USD Tether', 'networks': [], 'precision': 6, 'sort_priority': 4, 'symbol': 'USDT', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 16, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 4, 'name': 'Dogecoin', 'networks': [], 'precision': 8, 'sort_priority': 100, 'symbol': 'DOGE', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 17, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 4, 'name': 'Solana', 'networks': [], 'precision': 8, 'sort_priority': 7, 'symbol': 'SOL', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 18, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 4, 'name': 'Avalanche', 'networks': [], 'precision': 8, 'sort_priority': 100, 'symbol': 'AVAX', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 19, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 4, 'name': 'Ripple', 'networks': [], 'precision': 8, 'sort_priority': 5, 'symbol': 'XRP', 'variable_withdrawal_fee': '0.000000000000000000'}, {'base_withdrawal_fee': '0.000000000000000000', 'id': 20, 'interest_credit': False, 'interest_slabs': None, 'kyc_deposit_limit': '0.000000000000000000', 'kyc_withdrawal_limit': '0.000000000000000000', 'min_withdrawal_amount': '0.000000000000000000', 'minimum_precision': 8, 'name': 'Polygon', 'networks': [], 'precision': 8, 's ...

# %% [markdown]
# ## Filter ATM Strike

# %%
tickRes = delta_client.get_ticker('BTCUSD')
tickRes

tickRes['spot_price']
# Out:
# '116396.4'

# %%
spotPrice = float(tickRes['spot_price'])
spotPrice
# Out:
# 116396.4

# %%
atmStrike = round(float(spotPrice)/200)*200

atmStrike
# Out:
# 116400

# %%
expDate = datetime.now() + timedelta(days= 1)
expDate
# Out:
# datetime.datetime(2025, 8, 8, 19, 56, 23, 997806)

# %%
expStr = expDate.strftime("%d%m%y")
expStr
# Out:
# '080825'

# %%
callSym  = f'C-BTC-{atmStrike}-{expStr}'
callSym
# Out:
# 'C-BTC-116400-080825'

# %%
putSym  = f'P-BTC-{atmStrike}-{expStr}'
putSym
# Out:
# 'P-BTC-116400-080825'

# %%
delta_client.get_product(putSym)
# Out:
# {'initial_margin_scaling_factor': '0.000002',
#  'maintenance_margin_scaling_factor': '0.000001',
#  'settlement_price': None,
#  'auction_finish_time': None,
#  'maker_commission_rate': '0.00015',
#  'basis_factor_max_limit': '10.95',
#  'state': 'live',
#  'quoting_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'disruption_reason': None,
#  'short_description': 'BTC  Put',
#  'id': 88432,
#  'strike_price': '116400',
#  'default_leverage': '100.000000000000000000',
#  'position_size_limit': 255633,
#  'price_band': '2',
#  'liquidation_penalty_factor': '0.5',
#  'tick_size': '0.1',
#  'impact_size': 200,
#  'taker_commission_rate': '0.00015',
#  'contract_type': 'put_options',
#  'barrier_price': None,
#  'spot_index': {'config': {'price_alert_enabled': True,
#    'quoting_asset': 'USD',
#    'service_id': 1,
#    'underlying_asset': 'BTC'},
#   'constituent_exchanges': [],
#   'constituent_indices': {'expression': '${e1} * ${e2}',
#    'indices': {'e1': '.DEXBTUSDT', 'e2': '.DEUSDTUSD'}},
#   'description': 'Bitcoin spot price index quoted in US Dollar',
#   'health_interval': 300,
#   'id': 14,
#   'impact_size': '1.000000000000000000',
#   'index_type': 'spot_pair',
#   'is_composite': True,
#   'price_method': 'orderbook',
#   'quoting_asset_id': 14,
#   'symbol': '.DEXBTUSD',
#   'tick_size': '0.500000000000000000',
#   'underlying_asset_id': 13},
#  'product_specs': {'backup_vol_expiry_time': 31536000,
#   'isolated_liq_penalty_factor': 0.0005,
#   'isolated_liq_premium_penalty_factor': 0.2,
#   'max_deviation_from_external_vol': 0.75,
#   'max_lower_deviation_from_external_vol': 0.75,
#   'max_upper_deviation_from_external_vol': 0.5,
#   'max_volatility': 3,
#   'min_volatility': 0.1,
#   'only_reduce_only_orders_allowed': False,
#   'premium_commission_rate': 0.1,
#   'vol_calculation_method': 'orderbook',
#   'vol_expiry_time': 31536000},
#  'launch_time': '2025-08-06T18:00:02Z',
#  'symbol': 'P-BTC-116400-080825',
#  'settlement_time': '2025-08-08T12:00:00Z',
#  'trading_status': 'operational',
#  'notional_type': 'vanilla',
#  'settling_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'underlying_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 13,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 4,
#   'name': 'Bitcoin',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 1,
#   'symbol': 'BTC',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'initial_margin': '0.5',
#  'insurance_fund_margin_contribution': '5',
#  'maintenance_margin': '0.25',
#  'is_quanto': False,
#  'contract_value': '0.001',
#  'max_leverage_notional': '200000',
#  'ui_config': {'default_trading_view_candle': '15',
#   'leverage_slider_values': [1, 2, 5, 10, 25, 50, 100, 200],
#   'price_clubbing_values': [0.1, 0.5, 1, 2.5, 5, 10],
#   'show_bracket_orders': False,
#   'sort_priority': 1,
#   'tags': []},
#  'funding_method': 'mark_price',
#  'annualized_funding': '10.95',
#  'description': 'BTC put option expiring on 8-8-2025',
#  'auction_start_time': '2025-08-06T18:00:02Z',
#  'contract_unit_currency': 'BTC'}

# %%
delta_client.get_product(callSym)
# Out:
# {'price_band': '2',
#  'underlying_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 13,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 4,
#   'name': 'Bitcoin',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 1,
#   'symbol': 'BTC',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'insurance_fund_margin_contribution': '5',
#  'ui_config': {'default_trading_view_candle': '15',
#   'leverage_slider_values': [1, 2, 5, 10, 25, 50, 100, 200],
#   'price_clubbing_values': [0.1, 0.5, 1, 2.5, 5, 10],
#   'show_bracket_orders': False,
#   'sort_priority': 1,
#   'tags': []},
#  'product_specs': {'backup_vol_expiry_time': 31536000,
#   'isolated_liq_penalty_factor': 0.0005,
#   'isolated_liq_premium_penalty_factor': 0.2,
#   'max_deviation_from_external_vol': 0.75,
#   'max_lower_deviation_from_external_vol': 0.75,
#   'max_upper_deviation_from_external_vol': 0.5,
#   'max_volatility': 3,
#   'min_volatility': 0.1,
#   'only_reduce_only_orders_allowed': False,
#   'premium_commission_rate': 0.1,
#   'vol_calculation_method': 'orderbook',
#   'vol_expiry_time': 31536000},
#  'symbol': 'C-BTC-116400-080825',
#  'position_size_limit': 255633,
#  'settlement_price': None,
#  'state': 'live',
#  'tick_size': '0.1',
#  'funding_method': 'mark_price',
#  'maintenance_margin': '0.25',
#  'spot_index': {'config': {'price_alert_enabled': True,
#    'quoting_asset': 'USD',
#    'service_id': 1,
#    'underlying_asset': 'BTC'},
#   'constituent_exchanges': [],
#   'constituent_indices': {'expression': '${e1} * ${e2}',
#    'indices': {'e1': '.DEXBTUSDT', 'e2': '.DEUSDTUSD'}},
#   'description': 'Bitcoin spot price index quoted in US Dollar',
#   'health_interval': 300,
#   'id': 14,
#   'impact_size': '1.000000000000000000',
#   'index_type': 'spot_pair',
#   'is_composite': True,
#   'price_method': 'orderbook',
#   'quoting_asset_id': 14,
#   'symbol': '.DEXBTUSD',
#   'tick_size': '0.500000000000000000',
#   'underlying_asset_id': 13},
#  'id': 88433,
#  'short_description': 'BTC  Call',
#  'trading_status': 'operational',
#  'notional_type': 'vanilla',
#  'launch_time': '2025-08-06T18:00:03Z',
#  'barrier_price': None,
#  'strike_price': '116400',
#  'initial_margin': '0.5',
#  'liquidation_penalty_factor': '0.5',
#  'is_quanto': False,
#  'contract_value': '0.001',
#  'impact_size': 200,
#  'auction_finish_time': None,
#  'maker_commission_rate': '0.00015',
#  'taker_commission_rate': '0.00015',
#  'annualized_funding': '10.95',
#  'quoting_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'default_leverage': '100.000000000000000000',
#  'settlement_time': '2025-08-08T12:00:00Z',
#  'contract_unit_currency': 'BTC',
#  'maintenance_margin_scaling_factor': '0.000001',
#  'disruption_reason': None,
#  'contract_type': 'call_options',
#  'max_leverage_notional': '200000',
#  'basis_factor_max_limit': '10.95',
#  'initial_margin_scaling_factor': '0.000002',
#  'settling_asset': {'base_withdrawal_fee': '0.000000000000000000',
#   'id': 14,
#   'interest_credit': False,
#   'interest_slabs': None,
#   'kyc_deposit_limit': '0.000000000000000000',
#   'kyc_withdrawal_limit': '0.000000000000000000',
#   'min_withdrawal_amount': '0.000000000000000000',
#   'minimum_precision': 2,
#   'name': 'US Dollar',
#   'networks': [],
#   'precision': 8,
#   'sort_priority': 3,
#   'symbol': 'USD',
#   'variable_withdrawal_fee': '0.000000000000000000'},
#  'description': 'BTC call option expiring on 8-8-2025',
#  'auction_start_time': '2025-08-06T18:00:03Z'}
