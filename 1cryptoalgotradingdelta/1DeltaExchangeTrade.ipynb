# %%
pip install delta-rest-client
# Out:
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# Requirement already satisfied: delta-rest-client in /opt/anaconda3/lib/python3.12/site-packages (1.0.12)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/opt/anaconda3/lib/python3.12/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Symbol Management / Ticker /Filter Options Strike

# %%
apikey = '0Kp22RxWZYsKmV0Rm6RVz4xdSBP1K6'
apiSecret = 'Ii61nGVhAODut5kcI0wRlelTaUV0EXfingCibfPQYnjZfkdpxCF7a4Q3WXu2'

# %%
from delta_rest_client import DeltaRestClient
import pandas as pd
from datetime import datetime , timedelta

delta_client = DeltaRestClient(
  base_url='https://api.india.delta.exchange',
  api_key=apikey,
  api_secret=apiSecret
)
delta_client

# %% [markdown]
# ## Get Master List

# %%
# Get symbol list
res = delta_client.get_product('')
symdf = pd.DataFrame(res)
symdf
# Out:
#                                 initial_margin_scaling_factor  \
# base_withdrawal_fee                                 0.0000025
# id                                                  0.0000025
# interest_credit                                     0.0000025
# interest_slabs                                      0.0000025
# kyc_deposit_limit                                   0.0000025
# kyc_withdrawal_limit                                0.0000025
# min_withdrawal_amount                               0.0000025
# minimum_precision                                   0.0000025
# name                                                0.0000025
# networks                                            0.0000025
# precision                                           0.0000025
# sort_priority                                       0.0000025
# symbol                                              0.0000025
# variable_withdrawal_fee                             0.0000025
# config                                              0.0000025
# constituent_exchanges                               0.0000025
# constituent_indices                                 0.0000025
# description                                         0.0000025
# health_interval                                     0.0000025
# impact_size                                         0.0000025
# index_type                                          0.0000025
# is_composite                                        0.0000025
# price_method                                        0.0000025
# quoting_asset_id                                    0.0000025
# tick_size                                           0.0000025
# underlying_asset_id                                 0.0000025
# funding_clamp_value                                 0.0000025
# isolated_liq_penalty_factor                         0.0000025
# only_reduce_only_orders_allowed                     0.0000025
# tags                                                0.0000025
# default_trading_view_candle                         0.0000025
# leverage_slider_values                              0.0000025
# price_clubbing_values                               0.0000025
# show_bracket_orders                                 0.0000025
#
#                                 maintenance_margin_scaling_factor  \
# base_withdrawal_fee                                    0.00000125
# id                                                     0.00000125
# interest_credit                                        0.00000125
# interest_slabs                                         0.00000125
# kyc_deposit_limit                                      0.00000125
# kyc_withdrawal_limit                                   0.00000125
# min_withdrawal_amount                                  0.00000125
# minimum_precision                                      0.00000125
# name                                                   0.00000125
# networks                                               0.00000125
# precision                                              0.00000125
# sort_priority                                          0.00000125
# symbol                                                 0.00000125
# variable_withdrawal_fee                                0.00000125
# config                                                 0.00000125
# constituent_exchanges                                  0.00000125
# constituent_indices                                    0.00000125
# description                                            0.00000125
# health_interval                                        0.00000125
# impact_size                                            0.00000125
# index_type                                             0.00000125
# is_composite                                           0.00000125
# price_method                                           0.00000125
# quoting_asset_id                                       0.00000125
# tick_size                                              0.00000125
# underlying_asset_id                                    0.00000125
# funding_clamp_value                                    0.00000125
# isolated_liq_penalty_factor                            0.00000125
# only_reduce_only_orders_allowed                        0.00000125
# tags                                                   0.00000125
# default_trading_view_candle                            0.00000125
# leverage_slider_values                                 0.00000125
# price_clubbing_values                                  0.00000125
# show_bracket_orders                                    0.00000125
#
#                                 settlement_price auction_finish_time  \
# base_withdrawal_fee                         None                None
# id                                          None                None
# interest_credit                             None                None
# interest_slabs                              None                None
# kyc_deposit_limit                           None                None
# kyc_withdrawal_limit                        None                None
# min_withdrawal_amount                       None                None
# minimum_precision                           None                None
# name                                        None                None
# networks                                    None                None
# precision                                   None                None
# sort_priority                               None                None
# symbol                                      None                None
# variable_withdrawal_fee                     None                None
# config                                      None                None
# constituent_exchanges                       None                None
# constituent_indices                         None                None
# description                                 None                None
# health_interval                             None                None
# impact_size                                 None                None
# index_type                                  None                None
# is_composite                                None                None
# price_method                                None                None
# quoting_asset_id                            None                None
# tick_size                                   None                None
# underlying_asset_id                         None                None
# funding_clamp_value                         None                None
# isolated_liq_penalty_factor                 None                None
# only_reduce_only_orders_allowed             None                None
# tags                                        None                None
# default_trading_view_candle                 None                None
# leverage_slider_values                      None                None
# price_clubbing_values                       None                None
# show_bracket_orders                         None                None
#
#                                 maker_commission_rate basis_factor_max_limit  \
# base_withdrawal_fee                            0.0002                  10.95
# id                                             0.0002                  10.95
# interest_credit                                0.0002                  10.95
# interest_slabs                                 0.0002                  10.95
# kyc_deposit_limit                              0.0002                  10.95
# kyc_withdrawal_limit                           0.0002                  10.95
# min_withdrawal_amount                          0.0002                  10.95
# minimum_precision                              0.0002                  10.95
# name                                           0.0002                  10.95
# networks                                       0.0002                  10.95
# precision                                      0.0002                  10.95
# sort_priority                                  0.0002                  10.95
# symbol                                         0.0002                  10.95
# variable_withdrawal_fee                        0.0002                  10.95
# config                                         0.0002                  10.95
# constituent_exchanges                          0.0002                  10.95
# constituent_indices                            0.0002                  10.95
# description                                    0.0002                  10.95
# health_interval                                0.0002                  10.95
# impact_size                                    0.0002                  10.95
# index_type                                     0.0002                  10.95
# is_composite                                   0.0002                  10.95
# price_method                                   0.0002                  10.95
# quoting_asset_id                               0.0002                  10.95
# tick_size                                      0.0002                  10.95
# underlying_asset_id                            0.0002                  10.95
# funding_clamp_value                            0.0002                  10.95
# isolated_liq_penalty_factor                    0.0002                  10.95
# only_reduce_only_orders_allowed                0.0002                  10.95
# tags                                           0.0002                  10.95
# default_trading_view_candle                    0.0002                  10.95
# leverage_slider_values                         0.0002                  10.95
# price_clubbing_values                          0.0002                  10.95
# show_bracket_orders                            0.0002                  10.95
#
#                                 state         quoting_asset disruption_reason  \
# base_withdrawal_fee              live  0.000000000000000000              None
# id                               live                    14              None
# interest_credit                  live                 False              None
# interest_slabs                   live                  None              None
# kyc_deposit_limit                live  0.000000000000000000              None
# kyc_withdrawal_limit             live  0.000000000000000000              None
# min_withdrawal_amount            live  0.000000000000000000              None
# minimum_precision                live                     2              None
# name                             live             US Dollar              None
# networks                         live                    []              None
# precision                        live                     8              None
# sort_priority                    live                     3              None
# symbol                           live                   USD              None
# variable_withdrawal_fee          live  0.000000000000000000              None
# config                           live                   NaN              None
# constituent_exchanges            live                   NaN              None
# constituent_indices              live                   NaN              None
# description                      live                   NaN              None
# health_interval                  live                   NaN              None
# impact_size                      live                   NaN              None
# index_type                       live                   NaN              None
# is_composite                     live                   NaN              None
# price_method                     live                   NaN              None
# quoting_asset_id                 live                   NaN              None
# tick_size                        live                   NaN              None
# underlying_asset_id              live                   NaN              None
# funding_clamp_value              live                   NaN              None
# isolated_liq_penalty_factor      live                   NaN              None
# only_reduce_only_orders_allowed  live                   NaN              None
# tags                             live                   NaN              None
# default_trading_view_candle      live                   NaN              None
# leverage_slider_values           live                   NaN              None
# price_clubbing_values            live                   NaN              None
# show_bracket_orders              live                   NaN              None
#
#                                  short_description  ...  maintenance_margin  \
# base_withdrawal_fee              Bitcoin Perpetual  ...                0.25
# id                               Bitcoin Perpetual  ...                0.25
# interest_credit                  Bitcoin Perpetual  ...                0.25
# interest_slabs                   Bitcoin Perpetual  ...                0.25
# kyc_deposit_limit                Bitcoin Perpetual  ...                0.25
# kyc_withdrawal_limit             Bitcoin Perpetual  ...                0.25
# min_withdrawal_amount            Bitcoin Perpetual  ...                0.25
# minimum_precision                Bitcoin Perpetual  ...                0.25
# name                             Bitcoin Perpetual  ...                0.25
# networks                         Bitcoin Perpetual  ...                0.25
# precision                        Bitcoin Perpetual  ...                0.25
# sort_priority                    Bitcoin Perpetual  ...                0.25
# symbol                           Bitcoin Perpetual  ...                0.25
# variable_withdrawal_fee          Bitcoin Perpetual  ...                0.25
# config                           Bitcoin Perpetual  ...                0.25
# constituent_exchanges            Bitcoin Perpetual  ...                0.25
# constituent_indices              Bitcoin Perpetual  ...                0.25
# description                      Bitcoin Perpetual  ...                0.25
# health_interval                  Bitcoin Perpetual  ...                0.25
# impact_size                      Bitcoin Perpetual  ...                0.25
# index_type                       Bitcoin Perpetual  ...                0.25
# is_composite                     Bitcoin Perpetual  ...                0.25
# price_method                     Bitcoin Perpetual  ...                0.25
# quoting_asset_id                 Bitcoin Perpetual  ...                0.25
# tick_size                        Bitcoin Perpetual  ...                0.25
# underlying_asset_id              Bitcoin Perpetual  ...                0.25
# funding_clamp_value              Bitcoin Perpetual  ...                0.25
# isolated_liq_penalty_factor      Bitcoin Perpetual  ...                0.25
# only_reduce_only_orders_allowed  Bitcoin Perpetual  ...                0.25
# tags                             Bitcoin Perpetual  ...                0.25
# default_trading_view_candle      Bitcoin Perpetual  ...                0.25
# leverage_slider_values           Bitcoin Perpetual  ...                0.25
# price_clubbing_values            Bitcoin Perpetual  ...                0.25
# show_bracket_orders              Bitcoin Perpetual  ...                0.25
#
#                                 is_quanto contract_value  \
# base_withdrawal_fee                 False          0.001
# id                                  False          0.001
# interest_credit                     False          0.001
# interest_slabs                      False          0.001
# kyc_deposit_limit                   False          0.001
# kyc_withdrawal_limit                False          0.001
# min_withdrawal_amount               False          0.001
# minimum_precision                   False          0.001
# name                                False          0.001
# networks                            False          0.001
# precision                           False          0.001
# sort_priority                       False          0.001
# symbol                              False          0.001
# variable_withdrawal_fee             False          0.001
# config                              False          0.001
# constituent_exchanges               False          0.001
# constituent_indices                 False          0.001
# description                         False          0.001
# health_interval                     False          0.001
# impact_size                         False          0.001
# index_type                          False          0.001
# is_composite                        False          0.001
# price_method                        False          0.001
# quoting_asset_id                    False          0.001
# tick_size                           False          0.001
# underlying_asset_id                 False          0.001
# funding_clamp_value                 False          0.001
# isolated_liq_penalty_factor         False          0.001
# only_reduce_only_orders_allowed     False          0.001
# tags                                False          0.001
# default_trading_view_candle         False          0.001
# leverage_slider_values              False          0.001
# price_clubbing_values               False          0.001
# show_bracket_orders                 False          0.001
#
#                                  max_leverage_notional  \
# base_withdrawal_fee                             100000
# id                                              100000
# interest_credit                                 100000
# interest_slabs                                  100000
# kyc_deposit_limit                               100000
# kyc_withdrawal_limit                            100000
# min_withdrawal_amount                           100000
# minimum_precision                               100000
# name                                            100000
# networks                                        100000
# precision                                       100000
# sort_priority                                   100000
# symbol                                          100000
# variable_withdrawal_fee                         100000
# config                                          100000
# constituent_exchanges                           100000
# constituent_indices                             100000
# description                                     100000
# health_interval                                 100000
# impact_size                                     100000
# index_type                                      100000
# is_composite                                    100000
# price_method                                    100000
# quoting_asset_id                                100000
# tick_size                                       100000
# underlying_asset_id                             100000
# funding_clamp_value                             100000
# isolated_liq_penalty_factor                     100000
# only_reduce_only_orders_allowed                 100000
# tags                                            100000
# default_trading_view_candle                     100000
# leverage_slider_values                          100000
# price_clubbing_values                           100000
# show_bracket_orders                             100000
#
#                                                       ui_config  \
# base_withdrawal_fee                                         NaN
# id                                                          NaN
# interest_credit                                             NaN
# interest_slabs                                              NaN
# kyc_deposit_limit                                           NaN
# kyc_withdrawal_limit                                        NaN
# min_withdrawal_amount                                       NaN
# minimum_precision                                           NaN
# name                                                        NaN
# networks                                                    NaN
# precision                                                   NaN
# sort_priority                                                 1
# symbol                                                      NaN
# variable_withdrawal_fee                                     NaN
# config                                                      NaN
# constituent_exchanges                                       NaN
# constituent_indices                                         NaN
# description                                                 NaN
# health_interval                                             NaN
# impact_size                                                 NaN
# index_type                                                  NaN
# is_composite                                                NaN
# price_method                                                NaN
# quoting_asset_id                                            NaN
# tick_size                                                   NaN
# underlying_asset_id                                         NaN
# funding_clamp_value                                         NaN
# isolated_liq_penalty_factor                                 NaN
# only_reduce_only_orders_allowed                             NaN
# tags                                                         []
# default_trading_view_candle                                  15
# leverage_slider_values           [1, 10, 25, 50, 100, 150, 200]
# price_clubbing_values                          [0.5, 1, 10, 50]
# show_bracket_orders                                       False
#
#                                 funding_method annualized_funding  \
# base_withdrawal_fee                 mark_price              10.95
# id                                  mark_price              10.95
# interest_credit                     mark_price              10.95
# interest_slabs                      mark_price              10.95
# kyc_deposit_limit                   mark_price              10.95
# kyc_withdrawal_limit                mark_price              10.95
# min_withdrawal_amount               mark_price              10.95
# minimum_precision                   mark_price              10.95
# name                                mark_price              10.95
# networks                            mark_price              10.95
# precision                           mark_price              10.95
# sort_priority                       mark_price              10.95
# symbol                              mark_price              10.95
# variable_withdrawal_fee             mark_price              10.95
# config                              mark_price              10.95
# constituent_exchanges               mark_price              10.95
# constituent_indices                 mark_price              10.95
# description                         mark_price              10.95
# health_interval                     mark_price              10.95
# impact_size                         mark_price              10.95
# index_type                          mark_price              10.95
# is_composite                        mark_price              10.95
# price_method                        mark_price              10.95
# quoting_asset_id                    mark_price              10.95
# tick_size                           mark_price              10.95
# underlying_asset_id                 mark_price              10.95
# funding_clamp_value                 mark_price              10.95
# isolated_liq_penalty_factor         mark_price              10.95
# only_reduce_only_orders_allowed     mark_price              10.95
# tags                                mark_price              10.95
# default_trading_view_candle         mark_price              10.95
# leverage_slider_values              mark_price              10.95
# price_clubbing_values               mark_price              10.95
# show_bracket_orders                 mark_price              10.95
#
#                                                                        description  \
# base_withdrawal_fee              Bitcoin Perpetual futures, quoted, settled & m...
# id                               Bitcoin Perpetual futures, quoted, settled & m...
# interest_credit                  Bitcoin Perpetual futures, quoted, settled & m...
# interest_slabs                   Bitcoin Perpetual futures, quoted, settled & m...
# kyc_deposit_limit                Bitcoin Perpetual futures, quoted, settled & m...
# kyc_withdrawal_limit             Bitcoin Perpetual futures, quoted, settled & m...
# min_withdrawal_amount            Bitcoin Perpetual futures, quoted, settled & m...
# minimum_precision                Bitcoin Perpetual futures, quoted, settled & m...
# name                             Bitcoin Perpetual futures, quoted, settled & m...
# networks                         Bitcoin Perpetual futures, quoted, settled & m...
# precision                        Bitcoin Perpetual futures, quoted, settled & m...
# sort_priority                    Bitcoin Perpetual futures, quoted, settled & m...
# symbol                           Bitcoin Perpetual futures, quoted, settled & m...
# variable_withdrawal_fee          Bitcoin Perpetual futures, quoted, settled & m...
# config                           Bitcoin Perpetual futures, quoted, settled & m...
# constituent_exchanges            Bitcoin Perpetual futures, quoted, settled & m...
# constituent_indices              Bitcoin Perpetual futures, quoted, settled & m...
# description                      Bitcoin Perpetual futures, quoted, settled & m...
# health_interval                  Bitcoin Perpetual futures, quoted, settled & m...
# impact_size                      Bitcoin Perpetual futures, quoted, settled & m...
# index_type                       Bitcoin Perpetual futures, quoted, settled & m...
# is_composite                     Bitcoin Perpetual futures, quoted, settled & m...
# price_method                     Bitcoin Perpetual futures, quoted, settled & m...
# quoting_asset_id                 Bitcoin Perpetual futures, quoted, settled & m...
# tick_size                        Bitcoin Perpetual futures, quoted, settled & m...
# underlying_asset_id              Bitcoin Perpetual futures, quoted, settled & m...
# funding_clamp_value              Bitcoin Perpetual futures, quoted, settled & m...
# isolated_liq_penalty_factor      Bitcoin Perpetual futures, quoted, settled & m...
# only_reduce_only_orders_allowed  Bitcoin Perpetual futures, quoted, settled & m...
# tags                             Bitcoin Perpetual futures, quoted, settled & m...
# default_trading_view_candle      Bitcoin Perpetual futures, quoted, settled & m...
# leverage_slider_values           Bitcoin Perpetual futures, quoted, settled & m...
# price_clubbing_values            Bitcoin Perpetual futures, quoted, settled & m...
# show_bracket_orders              Bitcoin Perpetual futures, quoted, settled & m...
#
#                                    auction_start_time contract_unit_currency
# base_withdrawal_fee              2025-07-27T05:47:41Z                    BTC
# id                               2025-07-27T05:47:41Z                    BTC
# interest_credit                  2025-07-27T05:47:41Z                    BTC
# interest_slabs                   2025-07-27T05:47:41Z                    BTC
# kyc_deposit_limit                2025-07-27T05:47:41Z                    BTC
# kyc_withdrawal_limit             2025-07-27T05:47:41Z                    BTC
# min_withdrawal_amount            2025-07-27T05:47:41Z                    BTC
# minimum_precision                2025-07-27T05:47:41Z                    BTC
# name                             2025-07-27T05:47:41Z                    BTC
# networks                         2025-07-27T05:47:41Z                    BTC
# precision                        2025-07-27T05:47:41Z                    BTC
# sort_priority                    2025-07-27T05:47:41Z                    BTC
# symbol                           2025-07-27T05:47:41Z                    BTC
# variable_withdrawal_fee          2025-07-27T05:47:41Z                    BTC
# config                           2025-07-27T05:47:41Z                    BTC
# constituent_exchanges            2025-07-27T05:47:41Z                    BTC
# constituent_indices              2025-07-27T05:47:41Z                    BTC
# description                      2025-07-27T05:47:41Z                    BTC
# health_interval                  2025-07-27T05:47:41Z                    BTC
# impact_size                      2025-07-27T05:47:41Z                    BTC
# index_type                       2025-07-27T05:47:41Z                    BTC
# is_composite                     2025-07-27T05:47:41Z                    BTC
# price_method                     2025-07-27T05:47:41Z                    BTC
# quoting_asset_id                 2025-07-27T05:47:41Z                    BTC
# tick_size                        2025-07-27T05:47:41Z                    BTC
# underlying_asset_id              2025-07-27T05:47:41Z                    BTC
# funding_clamp_value              2025-07-27T05:47:41Z                    BTC
# isolated_liq_penalty_factor      2025-07-27T05:47:41Z                    BTC
# only_reduce_only_orders_allowed  2025-07-27T05:47:41Z                    BTC
# tags                             2025-07-27T05:47:41Z                    BTC
# default_trading_view_candle      2025-07-27T05:47:41Z                    BTC
# leverage_slider_values           2025-07-27T05:47:41Z                    BTC
# price_clubbing_values            2025-07-27T05:47:41Z                    BTC
# show_bracket_orders              2025-07-27T05:47:41Z                    BTC
#
# [34 rows x 42 columns]

# %%
symdf.contract_type.unique()
# Out:
# array(['perpetual_futures'], dtype=object)

# %%
symdf.iloc[0]
# Out:
# initial_margin_scaling_factor                                                 0.0000025
# maintenance_margin_scaling_factor                                            0.00000125
# settlement_price                                                                   None
# auction_finish_time                                                                None
# maker_commission_rate                                                            0.0002
# basis_factor_max_limit                                                            10.95
# state                                                                              live
# quoting_asset                                                      0.000000000000000000
# disruption_reason                                                                  None
# short_description                                                     Bitcoin Perpetual
# id                                                                                   27
# strike_price                                                                       None
# default_leverage                                                 200.000000000000000000
# position_size_limit                                                              229167
# price_band                                                                            5
# liquidation_penalty_factor                                                          0.5
# tick_size                                                                           0.5
# impact_size                                                                       10000
# taker_commission_rate                                                            0.0005
# contract_type                                                         perpetual_futures
# barrier_price                                                                      None
# spot_index                                                                          NaN
# product_specs                                                                       NaN
# launch_time                                                        2023-12-18T13:10:39Z
# symbol                                                                           BTCUSD
# settlement_time                                                                    None
# trading_status                                                              operational
# notional_type                                                                   vanilla
# settling_asset                                                     0.000000000000000000
# underlying_asset                                                   0.000000000000000000
# initial_margin                                                                      0.5
# insurance_fund_margin_contribution                                                    5
# maintenance_margin                                                                 0.25
# is_quanto                                                                         False
# contract_value                                                                    0.001
# max_leverage_notional                                                            100000
# ui_config                                                                           NaN
# funding_method                                                               mark_price
# annualized_funding                                                                10.95
# description                           Bitcoin Perpetual futures, quoted, settled & m...
# auction_start_time                                                 2025-07-27T05:47:41Z
# contract_unit_currency                                                              BTC
# Name: base_withdrawal_fee, dtype: object

# %%
symdf['settlement_time'] =pd.to_datetime(symdf['settlement_time'], utc=True)
symdf['expiry'] = symdf['settlement_time'].dt.date
symdf

# %%
expiryDate= datetime.now() +  timedelta(days=1)
btcdf = symdf[(symdf.expiry ==expiryDate.date() )& (symdf.contract_unit_currency == 'BTC') ]
btcdf

# %%
btcdf[btcdf.contract_type == 'call_options']

# %% [markdown]
# ## Get product by ID

# %%
delta_client.get_product('63146')

# %%
delta_client.get_product('C-ETH-2860-250225')

# %% [markdown]
# ## Get Ticker

# %%
# Get Ticker
delta_client.get_ticker('BTCUSD')

# %%
delta_client.get_ticker('C-BTC-91600-240225')

# %%
tickRes = delta_client.get_ticker('')
tickDf = pd.DataFrame(tickRes)
tickDf

# %%
tickRes = delta_client.get_ticker('?contract_types=put_options')
tickDf = pd.DataFrame(tickRes)
tickDf

# %%
import requests
headers = {
  'Accept': 'application/json'
}

r = requests.get('https://api.india.delta.exchange/v2/indices', params={

}, headers = headers)

r.json()

# %% [markdown]
# ## Filter ATM Strike

# %%
tickRes = delta_client.get_ticker('BTCUSD')
tickRes

tickRes['spot_price']

spotPrice = float(tickRes['spot_price'])
spotPrice

atmStrike = round(float(spotPrice)/200)*200

atmStrike



expDate = datetime.now() + timedelta(days= 1)
expDate



expStr = expDate.strftime("%d%m%y")
expStr


callSym  = f'C-BTC-{atmStrike}-{expStr}'
callSym


putSym  = f'P-BTC-{atmStrike}-{expStr}'
putSym


delta_client.get_product(putSym)


delta_client.get_product(callSym)
